# %%
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import math
import time
import random
import requests
import json
import ast

# %%
df = pd.read_csv('../ai_model_data/raw_data/Model_06_15.csv')

# %%
list(df['id'])
# Out:
# ['albert/albert-base-v1',
#  'albert/albert-base-v2',
#  'albert/albert-large-v1',
#  'albert/albert-large-v2',
#  'albert/albert-xlarge-v1',
#  'albert/albert-xlarge-v2',
#  'albert/albert-xxlarge-v1',
#  'albert/albert-xxlarge-v2',
#  'google-bert/bert-base-cased-finetuned-mrpc',
#  'google-bert/bert-base-cased',
#  'google-bert/bert-base-chinese',
#  'google-bert/bert-base-german-cased',
#  'google-bert/bert-base-german-dbmdz-cased',
#  'google-bert/bert-base-german-dbmdz-uncased',
#  'google-bert/bert-base-multilingual-cased',
#  'google-bert/bert-base-multilingual-uncased',
#  'google-bert/bert-base-uncased',
#  'google-bert/bert-large-cased-whole-word-masking-finetuned-squad',
#  'google-bert/bert-large-cased-whole-word-masking',
#  'google-bert/bert-large-cased',
#  'google-bert/bert-large-uncased-whole-word-masking-finetuned-squad',
#  'google-bert/bert-large-uncased-whole-word-masking',
#  'google-bert/bert-large-uncased',
#  'almanach/camembert-base',
#  'Salesforce/ctrl',
#  'distilbert/distilbert-base-cased-distilled-squad',
#  'distilbert/distilbert-base-cased',
#  'distilbert/distilbert-base-german-cased',
#  'distilbert/distilbert-base-multilingual-cased',
#  'distilbert/distilbert-base-uncased-distilled-squad',
#  'distilbert/distilbert-base-uncased-finetuned-sst-2-english',
#  'distilbert/distilbert-base-uncased',
#  'distilbert/distilgpt2',
#  'distilbert/distilroberta-base',
#  'openai-community/gpt2-large',
#  'openai-community/gpt2-medium',
#  'openai-community/gpt2-xl',
#  'openai-community/gpt2',
#  'openai-community/openai-gpt',
#  'openai-community/roberta-base-openai-detector',
#  'FacebookAI/roberta-base',
#  'FacebookAI/roberta-large-mnli',
#  'openai-community/roberta-large-openai-detector',
#  'FacebookAI/roberta-large',
#  'google-t5/t5-11b',
#  'google-t5/t5-3b',
#  'google-t5/t5-base',
#  'google-t5/t5-large',
#  'google-t5/t5-small',
#  'transfo-xl/transfo-xl-wt103',
#  'FacebookAI/xlm-clm-ende-1024',
#  'FacebookAI/xlm-clm-enfr-1024',
#  'FacebookAI/xlm-mlm-100-1280',
#  'FacebookAI/xlm-mlm-17-1280',
#  'FacebookAI/xlm-mlm-en-2048',
#  'FacebookAI/xlm-mlm-ende-1024',
#  'FacebookAI/xlm-mlm-enfr-1024',
#  'FacebookAI/xlm-mlm-enro-1024',
#  'FacebookAI/xlm-mlm-tlm-xnli15-1024',
#  'FacebookAI/xlm-mlm-xnli15-1024',
#  'FacebookAI/xlm-roberta-base',
#  'FacebookAI/xlm-roberta-large-finetuned-conll02-dutch',
#  'FacebookAI/xlm-roberta-large-finetuned-conll02-spanish',
#  'FacebookAI/xlm-roberta-large-finetuned-conll03-english',
#  'FacebookAI/xlm-roberta-large-finetuned-conll03-german',
#  'FacebookAI/xlm-roberta-large',
#  'xlnet/xlnet-base-cased',
#  'xlnet/xlnet-large-cased',
#  '007J/smile',
#  '0307061430/xuangou',
#  '09panesara/distilbert-base-uncased-finetuned-cola',
#  '0x7o/keyt5-base',
#  '0x7o/keyt5-large',
#  '0xDEADBEA7/DialoGPT-small-rick',
#  '123123/ghfk',
#  '123456/Arcanegan',
#  '1234567/1234567',
#  '123abhiALFLKFO/albert-base-v2-finetuned-sst2',
#  '123abhiALFLKFO/albert-base-v2-yelp-polarity-finetuned-sst2',
#  '123abhiALFLKFO/distilbert-base-uncased-finetuned-cola',
#  '123addfg/ar',
#  '123www/test_model',
#  '13048909972/wav2vec2-common_voice-tr-demo',
#  '13048909972/wav2vec2-large-xls-r-300m-tr-colab',
#  '13048909972/wav2vec2-large-xlsr-53_common_voice_20211210112254',
#  '13048909972/wav2vec2-large-xlsr-53_common_voice_20211211085606',
#  '13306330378/huiqi_model',
#  '13on/gpt2-wishes',
#  '13on/kw2t-wishes',
#  '13onn/gpt2-wishes-2',
#  '13onnn/gpt2-wish',
#  '1503277708/namo',
#  '1575/7447',
#  '1712871/manual_vn_electra_small',
#  '1757968399/tinybert_4_312_1200',
#  '17luke/wav2vec2-large-xls-r-300m-icelandic-samromur',
#  '18811449050/bert_cn_finetuning',
#  '18811449050/bert_finetuning_test',
#  '1Basco/DialoGPT-small-jake',
#  '1n3skh/idk',
#  '202015004/wav2vec2-base-TLT-Shreya-trial',
#  '202015004/wav2vec2-base-timit-demo-colab',
#  '202015004/wav2vec2-base-timit-trial_by_SHREYA',
#  '275Gameplay/test',
#  '2early4coffee/DialoGPT-medium-deadpool',
#  '2early4coffee/DialoGPT-small-deadpool',
#  '2umm3r/bert-base-uncased-finetuned-cls',
#  '2umm3r/distilbert-base-uncased-finetuned-cola',
#  '3koozy/gpt2-HxH',
#  '3zooze/Dd',
#  'Akshay-Vs/AI',
#  '511663/bert_finetuning_test',
#  '54Tor/test',
#  '5dimension/test',
#  '609ead0502/test',
#  '61birds/distilbert-base-uncased-finetuned-cola',
#  '842458199/model_name',
#  '850886470/xxy_gpt2_chinese',
#  '873101411/distilbert-base-uncased-finetuned-squad',
#  '91Rodman/111',
#  '923/distilbert-base-uncased-finetuned-squad',
#  '9pinus/macbert-base-chinese-medical-collation',
#  '9pinus/macbert-base-chinese-medicine-recognition',
#  'A-bhimany-u08/bert-base-cased-qqp',
#  'AAli/bert-base-cased-wikitext2',
#  'AAli/bert-base-uncased-finetuned-swag',
#  'AAli/distilbert-base-uncased-finetuned-cola',
#  'AAli/distilbert-base-uncased-finetuned-ner',
#  'AAli/distilbert-base-uncased-finetuned-squad',
#  'AAli/distilgpt2-finetuned-wikitext2',
#  'AAli/gpt2-wikitext2',
#  'AAli/my-new-shiny-tokenizer',
#  'AAli/opus-mt-en-ro-finetuned-en-to-ro',
#  'AAli/t5-small-finetuned-xsum',
#  'AAli/wav2vec2-base-demo-colab',
#  'AAli/wav2vec2-base-finetuned-ks',
#  'ABBHISHEK/DialoGPT-small-harrypotter',
#  'AG/pretraining',
#  'AHussain0418/distillbert-truth-detector',
#  'AI-Ahmed/DisDistilBert-sst-N-Grams-en',
#  'AI-Growth-Lab/PatentSBERTa',
#  'AI-Lab-Makerere/en_lg',
#  'AI-Lab-Makerere/lg_en',
#  'AI-Nordics/bert-large-swedish-cased',
#  'IssakaAI/wav2vec2-large-xls-r-300m-turkish-colab',
#  'AI4Sec/cyner-xlm-roberta-base',
#  'AI4Sec/cyner-xlm-roberta-large',
#  'AIDA-UPM/MSTSb_paraphrase-multilingual-MiniLM-L12-v2',
#  'AIDA-UPM/MSTSb_paraphrase-xlm-r-multilingual-v1',
#  'AIDA-UPM/MSTSb_stsb-xlm-r-multilingual',
#  'AIDA-UPM/bertweet-base-multi-mami',
#  'AIDA-UPM/mstsb-paraphrase-multilingual-mpnet-base-v2',
#  'AIDA-UPM/xlm-roberta-large-snli_mnli_xnli_fever_r1_r2_r3',
#  'AIDynamics/DialoGPT-medium-MentorDealerGuy',
#  'AJ/DialoGPT-small-ricksanchez',
#  'AJ/rick-ai',
#  'AJ/rick-bot',
#  'AJ/rick-discord-bot',
#  'AJ/rick-sanchez-bot',
#  'AJ-Dude/DialoGPT-small-harrypotter',
#  'AK/ak_nlp',
#  'AK270802/DialoGPT-small-harrypotter',
#  'AKMyscich/VetTrain-v1.2',
#  'AKulk/wav2vec2-base-timit-demo-colab',
#  'AKulk/wav2vec2-base-timit-epochs10',
#  'AKulk/wav2vec2-base-timit-epochs15',
#  'AKulk/wav2vec2-base-timit-epochs20',
#  'AKulk/wav2vec2-base-timit-epochs5',
#  'ALINEAR/albert-japanese-v2',
#  'ALINEAR/albert-japanese',
#  'ALaks96/distilbart-cnn-12-6',
#  'ARATHI/electra-small-discriminator-fintuned-cola',
#  'ARCYVILK/gpt2-bot',
#  'ARTeLab/it5-summarization-fanpage',
#  'ARTeLab/it5-summarization-ilpost',
#  'ARTeLab/it5-summarization-mlsum',
#  'ARTeLab/mbart-summarization-fanpage',
#  'ARTeLab/mbart-summarization-ilpost',
#  'ARTeLab/mbart-summarization-mlsum',
#  'ASCCCCCCCC/PENGMENGJIE-finetuned-emotion',
#  'ASCCCCCCCC/PENGMENGJIE',
#  'ASCCCCCCCC/PMJ',
#  'ASCCCCCCCC/bert-base-chinese-finetuned-amazon_zh',
#  'ASCCCCCCCC/bert-base-chinese-finetuned-amazon_zh_20000',
#  'ASCCCCCCCC/distilbert-base-chinese-amazon_zh_20000',
#  'ASCCCCCCCC/distilbert-base-multilingual-cased-amazon_zh_20000',
#  'ASCCCCCCCC/distilbert-base-uncased-finetuned-amazon_zh_20000',
#  'ASCCCCCCCC/distilbert-base-uncased-finetuned-clinc',
#  'AT/bert-base-uncased-finetuned-wikitext2',
#  'AT/distilbert-base-cased-finetuned-wikitext2',
#  'AT/distilgpt2-finetuned-wikitext2',
#  'AT/distilroberta-base-finetuned-wikitext2',
#  'ATGdev/DialoGPT-small-harrypotter',
#  'ATGdev/ai_ironman',
#  'AUBMC-AIM/MammoGANesis',
#  'AUBMC-AIM/OCTaGAN',
#  'AVAIYA/python-test',
#  'AVSilva/bertimbau-large-fine-tuned-md',
#  'AVSilva/bertimbau-large-fine-tuned-sd',
#  'AVeryRealHuman/DialoGPT-small-TonyStark',
#  'AWTStress/stress_classifier',
#  'AWTStress/stress_score',
#  'AZTEC/Arcane',
#  'Aakansha/hateSpeechClassification',
#  'Aakansha/hs',
#  'Aarav/MeanMadCrazy_HarryPotterBot',
#  'AaravMonkey/modelRepo',
#  'Aarbor/xlm-roberta-base-finetuned-marc-en',
#  'Pinwheel/wav2vec2-base-timit-demo-colab',
#  'Pinwheel/wav2vec2-large-xls-r-1b-hi-v2',
#  'Pinwheel/wav2vec2-large-xls-r-1b-hi',
#  'Pinwheel/wav2vec2-large-xls-r-1b-hindi',
#  'Pinwheel/wav2vec2-large-xls-r-300m-50-hi',
#  'Pinwheel/wav2vec2-large-xls-r-300m-hi-v2',
#  'Pinwheel/wav2vec2-large-xls-r-300m-hi-v3',
#  'Pinwheel/wav2vec2-large-xls-r-300m-hi',
#  'Pinwheel/wav2vec2-large-xls-r-300m-tr-colab',
#  'Pinwheel/wav2vec2-large-xlsr-53-hi',
#  'Ab0/autoencoder-keras-mnist-demo',
#  'Ab0/foo-model',
#  'Ab0/keras-dummy-functional-demo',
#  'Ab0/keras-dummy-model-mixin-demo',
#  'Ab0/keras-dummy-sequential-demo',
#  'Ab2021/bookst5',
#  'Abab/Test_Albert',
#  'AbdelrahmanZayed/my-awesome-model',
#  'AbderrahimRezki/DialoGPT-small-harry',
#  'AbderrahimRezki/HarryPotterBot',
#  'Abdou/arabert-base-algerian',
#  'Abdou/arabert-large-algerian',
#  'Abdou/arabert-medium-algerian',
#  'Abdou/arabert-mini-algerian',
#  'Abdullaziz/model1',
#  'AbdulmalikAdeyemo/wav2vec2-large-xls-r-300m-hausa',
#  'AbhijeetA/PIE',
#  'Abhilash/BERTBasePyTorch',
#  'AbhinavSaiTheGreat/DialoGPT-small-harrypotter',
#  'Abhishek4/Cuad_Finetune_roberta',
#  'Abi9x/DiabloGPT-large-Axel',
#  'AbidHasan95/movieHunt2',
#  'AbidineVall/my-new-shiny-tokenizer',
#  'Abirate/bert_fine_tuned_cola',
#  'Abirate/code_net_new_tokenizer_from_WPiece_bert_algorithm',
#  'Abirate/code_net_similarity_model_sub23_fbert',
#  'Abirate/gpt_3_finetuned_multi_x_science',
#  'Abobus/Fu',
#  'Abolior/audiobot',
#  'Abozoroov/Me',
#  'AbyV/test',
#  'AccurateIsaiah/DialoGPT-small-jefftastic',
#  'AccurateIsaiah/DialoGPT-small-mozark',
#  'AccurateIsaiah/DialoGPT-small-mozarkv2',
#  'AccurateIsaiah/DialoGPT-small-sinclair',
#  'ActivationAI/distilbert-base-uncased-finetuned-emotion',
#  'AdWeeb/HTI_mbert',
#  'Adalid1985/Adalidarcane',
#  'AdapterHub/bert-base-uncased-pf-anli_r3',
#  'AdapterHub/bert-base-uncased-pf-art',
#  'AdapterHub/bert-base-uncased-pf-boolq',
#  'AdapterHub/bert-base-uncased-pf-cola',
#  'AdapterHub/bert-base-uncased-pf-commonsense_qa',
#  'AdapterHub/bert-base-uncased-pf-comqa',
#  'AdapterHub/bert-base-uncased-pf-conll2000',
#  'AdapterHub/bert-base-uncased-pf-conll2003',
#  'AdapterHub/bert-base-uncased-pf-conll2003_pos',
#  'AdapterHub/bert-base-uncased-pf-copa',
#  'AdapterHub/bert-base-uncased-pf-cosmos_qa',
#  'AdapterHub/bert-base-uncased-pf-cq',
#  'AdapterHub/bert-base-uncased-pf-drop',
#  'AdapterHub/bert-base-uncased-pf-duorc_p',
#  'AdapterHub/bert-base-uncased-pf-duorc_s',
#  'AdapterHub/bert-base-uncased-pf-emo',
#  'AdapterHub/bert-base-uncased-pf-emotion',
#  'AdapterHub/bert-base-uncased-pf-fce_error_detection',
#  'AdapterHub/bert-base-uncased-pf-hellaswag',
#  'AdapterHub/bert-base-uncased-pf-hotpotqa',
#  'AdapterHub/bert-base-uncased-pf-imdb',
#  'AdapterHub/bert-base-uncased-pf-mit_movie_trivia',
#  'AdapterHub/bert-base-uncased-pf-mnli',
#  'AdapterHub/bert-base-uncased-pf-mrpc',
#  'AdapterHub/bert-base-uncased-pf-multirc',
#  'AdapterHub/bert-base-uncased-pf-newsqa',
#  'AdapterHub/bert-base-uncased-pf-pmb_sem_tagging',
#  'AdapterHub/bert-base-uncased-pf-qnli',
#  'AdapterHub/bert-base-uncased-pf-qqp',
#  'AdapterHub/bert-base-uncased-pf-quail',
#  'AdapterHub/bert-base-uncased-pf-quartz',
#  'AdapterHub/bert-base-uncased-pf-quoref',
#  'AdapterHub/bert-base-uncased-pf-race',
#  'AdapterHub/bert-base-uncased-pf-record',
#  'AdapterHub/bert-base-uncased-pf-rotten_tomatoes',
#  'AdapterHub/bert-base-uncased-pf-rte',
#  'AdapterHub/bert-base-uncased-pf-scicite',
#  'AdapterHub/bert-base-uncased-pf-scitail',
#  'AdapterHub/bert-base-uncased-pf-sick',
#  'AdapterHub/bert-base-uncased-pf-snli',
#  'AdapterHub/bert-base-uncased-pf-social_i_qa',
#  'AdapterHub/bert-base-uncased-pf-squad',
#  'AdapterHub/bert-base-uncased-pf-squad_v2',
#  'AdapterHub/bert-base-uncased-pf-sst2',
#  'AdapterHub/bert-base-uncased-pf-stsb',
#  'AdapterHub/bert-base-uncased-pf-swag',
#  'AdapterHub/bert-base-uncased-pf-trec',
#  'AdapterHub/bert-base-uncased-pf-ud_deprel',
#  'AdapterHub/bert-base-uncased-pf-ud_en_ewt',
#  'AdapterHub/bert-base-uncased-pf-ud_pos',
#  'AdapterHub/bert-base-uncased-pf-wic',
#  'AdapterHub/bert-base-uncased-pf-wikihop',
#  'AdapterHub/bert-base-uncased-pf-winogrande',
#  'AdapterHub/bert-base-uncased-pf-wnut_17',
#  'AdapterHub/bert-base-uncased-pf-yelp_polarity',
#  'AdapterHub/bioASQyesno',
#  'AdapterHub/narrativeqa',
#  'AdapterHub/roberta-base-pf-anli_r3',
#  'AdapterHub/roberta-base-pf-art',
#  'AdapterHub/roberta-base-pf-boolq',
#  'AdapterHub/roberta-base-pf-cola',
#  'AdapterHub/roberta-base-pf-commonsense_qa',
#  'AdapterHub/roberta-base-pf-comqa',
#  'AdapterHub/roberta-base-pf-conll2000',
#  'AdapterHub/roberta-base-pf-conll2003',
#  'AdapterHub/roberta-base-pf-conll2003_pos',
#  'AdapterHub/roberta-base-pf-copa',
#  'AdapterHub/roberta-base-pf-cosmos_qa',
#  'AdapterHub/roberta-base-pf-cq',
#  'AdapterHub/roberta-base-pf-drop',
#  'AdapterHub/roberta-base-pf-duorc_p',
#  'AdapterHub/roberta-base-pf-duorc_s',
#  'AdapterHub/roberta-base-pf-emo',
#  'AdapterHub/roberta-base-pf-emotion',
#  'AdapterHub/roberta-base-pf-fce_error_detection',
#  'AdapterHub/roberta-base-pf-hellaswag',
#  'AdapterHub/roberta-base-pf-hotpotqa',
#  'AdapterHub/roberta-base-pf-imdb',
#  'AdapterHub/roberta-base-pf-mit_movie_trivia',
#  'AdapterHub/roberta-base-pf-mnli',
#  'AdapterHub/roberta-base-pf-mrpc',
#  'AdapterHub/roberta-base-pf-multirc',
#  'AdapterHub/roberta-base-pf-newsqa',
#  'AdapterHub/roberta-base-pf-pmb_sem_tagging',
#  'AdapterHub/roberta-base-pf-qnli',
#  'AdapterHub/roberta-base-pf-qqp',
#  'AdapterHub/roberta-base-pf-quail',
#  'AdapterHub/roberta-base-pf-quartz',
#  'AdapterHub/roberta-base-pf-quoref',
#  'AdapterHub/roberta-base-pf-race',
#  'AdapterHub/roberta-base-pf-record',
#  'AdapterHub/roberta-base-pf-rotten_tomatoes',
#  'AdapterHub/roberta-base-pf-rte',
#  'AdapterHub/roberta-base-pf-scicite',
#  'AdapterHub/roberta-base-pf-scitail',
#  'AdapterHub/roberta-base-pf-sick',
#  'AdapterHub/roberta-base-pf-snli',
#  'AdapterHub/roberta-base-pf-social_i_qa',
#  'AdapterHub/roberta-base-pf-squad',
#  'AdapterHub/roberta-base-pf-squad_v2',
#  'AdapterHub/roberta-base-pf-sst2',
#  'AdapterHub/roberta-base-pf-stsb',
#  'AdapterHub/roberta-base-pf-swag',
#  'AdapterHub/roberta-base-pf-trec',
#  'AdapterHub/roberta-base-pf-ud_deprel',
#  'AdapterHub/roberta-base-pf-ud_en_ewt',
#  'AdapterHub/roberta-base-pf-ud_pos',
#  'AdapterHub/roberta-base-pf-wic',
#  'AdapterHub/roberta-base-pf-wikihop',
#  'AdapterHub/roberta-base-pf-winogrande',
#  'AdapterHub/roberta-base-pf-wnut_17',
#  'AdapterHub/roberta-base-pf-yelp_polarity',
#  'Adarsh123/distilbert-base-uncased-finetuned-ner',
#  'Addixz/Sanyx',
#  'Adharsh2608/DialoGPT-small-harrypotter',
#  'AdharshJolly/HarryPotterBot-Model',
#  'Adi2K/Priv-Consent',
#  'AdiShenoy0807/DialoGPT-medium-joshua',
#  'Adielcane/Adiel',
#  'Adielcane/Adielcane',
#  'Adil617/wav2vec2-base-timit-demo-colab',
#  'Adinda/Adinda',
#  'Adityanawal/testmodel_1',
#  'Adnan/UrduNewsHeadlines',
#  'AdrianGzz/DialoGPT-small-harrypotter',
#  'Adrianaforididk/Jinx',
#  'Advertisement/FischlUWU',
#  'Aero/Tsubomi-Haruno',
#  'Aeroxas/Botroxas-small',
#  'Aeskybunnie/Me',
#  'AetherIT/DialoGPT-small-Hal',
#  'AethiQs-Max/AethiQs_GemBERT_bertje_50k',
#  'AethiQs-Max/aethiqs-base_bertje-data_rotterdam-epochs_10',
#  'AethiQs-Max/aethiqs-base_bertje-data_rotterdam-epochs_30-epoch_30',
#  'AethiQs-Max/cross_encoder',
#  'AethiQs-Max/s3-v1-20_epochs',
#  'Aftabhussain/Tomato_Leaf_Classifier',
#  'Ahda/M',
#  'Ahmad/parsT5-base',
#  'Ahmad/parsT5',
#  'Ahmadatiya97/Alannah',
#  'Ahmadvakili/A',
#  'Ahmed59/Demo-Team-5-SIAD',
#  'AhmedBou/TuniBert',
#  'AhmedHassan19/model',
#  'AhmedSSoliman/MarianCG-CoNaLa',
#  'Ahmedahmed/Wewe',
#  'Ahren09/distilbert-base-uncased-finetuned-cola',
#  'AiPorter/DialoGPT-small-Back_to_the_future',
#  'Aibox/DialoGPT-small-rick',
#  'Aidan8756/stephenKingModel',
#  'AidenGO/KDXF_Bert4MaskedLM',
#  'AigizK/wav2vec2-large-xls-r-300m-bashkir-cv7_no_lm',
#  'AigizK/wav2vec2-large-xls-r-300m-bashkir-cv7_opt',
#  'AimB/konlpy_berttokenizer_helsinki',
#  'AimB/mT5-en-kr-aihub-netflix',
#  'AimB/mT5-en-kr-natural',
#  'AimB/mT5-en-kr-opus',
#  'Aimendo/Triage',
#  'Aimendo/autonlp-triage-35248482',
#  'Ajay191191/autonlp-Test-530014983',
#  'Ajaykannan6/autonlp-manthan-16122692',
#  'Ajteks/Chatbot',
#  'AkaiSnow/Rick_bot',
#  'Akame/Vi',
#  'Akaramhuggingface/News',
#  'Akari/albert-base-v2-finetuned-squad',
#  'Akash7897/bert-base-cased-wikitext2',
#  'Akash7897/distilbert-base-uncased-finetuned-cola',
#  'Akash7897/distilbert-base-uncased-finetuned-sst2',
#  'Akash7897/fill_mask_model',
#  'Akash7897/gpt2-wikitext2',
#  'Akash7897/my-newtokenizer',
#  'Akash7897/test-clm',
#  'Akashamba/distilbert-base-uncased-finetuned-ner',
#  'Akashpb13/Central_kurdish_xlsr',
#  'Akashpb13/Galician_xlsr',
#  'Akashpb13/Hausa_xlsr',
#  'Akashpb13/Kabyle_xlsr',
#  'Akashpb13/Swahili_xlsr',
#  'Akashpb13/xlsr_hungarian_new',
#  'Akashpb13/xlsr_kurmanji_kurdish',
#  'Akashpb13/xlsr_maltese_wav2vec2',
#  'Akbarariza/Anjar',
#  'Akira-Yanagi/distilbert-base-uncased-finetuned-cola',
#  'Akiva/Joke',
#  'Akjder/DialoGPT-small-harrypotter',
#  'Aklily/Lilys',
#  'AkshatSurolia/BEiT-FaceMask-Finetuned',
#  'AkshatSurolia/ConvNeXt-FaceMask-Finetuned',
#  'AkshatSurolia/DeiT-FaceMask-Finetuned',
#  'AkshatSurolia/ICD-10-Code-Prediction',
#  'AkshatSurolia/ViT-FaceMask-Finetuned',
#  'AkshayDev/BERT_Fine_Tuning',
#  'AkshaySg/GrammarCorrection',
#  'AkshaySg/LanguageIdentification',
#  'AkshaySg/gramCorrection',
#  'AkshaySg/langid',
#  'Akuva2001/SocialGraph',
#  'Al/mymodel',
#  'AlErysvi/Erys',
#  'Alaeddin/convbert-base-turkish-ner-cased',
#  'AlanDev/DallEMiniButBetter',
#  'AlanDev/dall-e-better',
#  'AlanDev/test',
#  'AlbertHSU/BertTEST',
#  'AlbertHSU/ChineseFoodBert',
#  'Alberto15Romero/GptNeo',
#  'AlchemistDude/DialoGPT-medium-Gon',
#  'Ale/Alen',
#  'Aleenbo/Arcane',
#  'Aleksandar/bert-srb-base-cased-oscar',
#  'Aleksandar/bert-srb-ner-setimes-lr',
#  'Aleksandar/bert-srb-ner-setimes',
#  'Aleksandar/bert-srb-ner',
#  'Aleksandar/distilbert-srb-base-cased-oscar',
#  'Aleksandar/distilbert-srb-ner-setimes-lr',
#  'Aleksandar/distilbert-srb-ner-setimes',
#  'Aleksandar/distilbert-srb-ner',
#  'Aleksandar/electra-srb-ner-setimes-lr',
#  'Aleksandar/electra-srb-ner-setimes',
#  'Aleksandar/electra-srb-ner',
#  'Aleksandar/electra-srb-oscar',
#  'Aleksandar1932/distilgpt2-rock',
#  'Aleksandar1932/gpt2-country',
#  'Aleksandar1932/gpt2-hip-hop',
#  'Aleksandar1932/gpt2-pop',
#  'Aleksandar1932/gpt2-rock-124439808',
#  'Aleksandar1932/gpt2-soul',
#  'Aleksandar1932/gpt2-spanish-classics',
#  'Aleksandra/distilbert-base-uncased-finetuned-squad',
#  'Aleksandra/herbert-base-cased-finetuned-squad',
#  'adorkin/xlm-roberta-en-ru-emoji',
#  'AlekseyKorshuk/bert',
#  'AlekseyKorshuk/comedy-scripts',
#  'AlekseyKorshuk/horror-scripts',
#  'AlekseyKulnevich/Pegasus-HeaderGeneration',
#  'AlekseyKulnevich/Pegasus-QuestionGeneration',
#  'AlekseyKulnevich/Pegasus-Summarization',
#  'Alerosae/SocratesGPT-2',
#  'Alessandro/model_name',
#  'AlexDemon/Alex',
#  'AlexKay/xlm-roberta-large-qa-multilingual-finedtuned-ru',
#  'AlexMaclean/sentence-compression-roberta',
#  'AlexMaclean/sentence-compression',
#  'AlexN/xls-r-300m-fr-0',
#  'AlexN/xls-r-300m-fr',
#  'AlexN/xls-r-300m-pt',
#  'AlexaMerens/Owl',
#  'AlexaRyck/KEITH',
#  'Alexander-Learn/bert-finetuned-ner-accelerate',
#  'Alexander-Learn/bert-finetuned-ner',
#  'Alexander-Learn/bert-finetuned-squad-accelerate',
#  'Alexander-Learn/bert-finetuned-squad',
#  'Alexandru/creative_copilot',
#  'AlexeyIgnatov/albert-xlarge-v2-squad-v2',
#  'AlexeyYazev/my-awesome-model',
#  'Alfia/anekdotes',
#  'AliPotter24/a',
#  'Alicanke/Wyau',
#  'Alifarsi/t5-small-finetuned-xsum',
#  'Aliraza47/BERT',
#  'Alireza-rw/testbot',
#  'Alireza1044/albert-base-v2-cola',
#  'Alireza1044/albert-base-v2-mnli',
#  'Alireza1044/albert-base-v2-mrpc',
#  'Alireza1044/albert-base-v2-qnli',
#  'Alireza1044/albert-base-v2-qqp',
#  'Alireza1044/albert-base-v2-rte',
#  'Alireza1044/albert-base-v2-sst2',
#  'Alireza1044/albert-base-v2-stsb',
#  'Alireza1044/albert-base-v2-wnli',
#  'Alireza1044/bert_classification_lm',
#  'Alireza1044/dwight_bert_lm',
#  'Alireza1044/michael_bert_lm',
#  'AlirezaBaneshi/testPersianQA',
#  'Aliskin/xlm-roberta-base-finetuned-marc',
#  'Aliyyu/Keren',
#  'AllwynJ/HarryBoy',
#  'Allybaby21/Allysai',
#  'Aloka/mbart50-ft-si-en',
#  'Alstractor/distilbert-base-uncased-finetuned-cola',
#  'Altidore/DuggFace',
#  'Alvenir/wav2vec2-base-da',
#  'Amalq/distilroberta-base-finetuned-MentalHealth',
#  'Amalq/distilroberta-base-finetuned-anxiety-depression',
#  'Amalq/roberta-base-finetuned-schizophreniaReddit2',
#  'AmanPriyanshu/DistilBert-Sentiment-Analysis',
#  'AmazonScience/qanlu',
#  'Amba/wav2vec2-large-xls-r-300m-tr-colab',
#  'Amba/wav2vec2-large-xls-r-300m-turkish-colab',
#  'aisoftware/Loquela',
#  'Amir99/toxic',
#  'AmirBialer/amirbialer-Classifier',
#  'AmirHussein/test',
#  'AmirServi/MyModel',
#  'Amirosein/distilbert_v1',
#  'Amirosein/roberta',
#  'Amit29/t5-small-finetuned-xsum',
#  'AmitT/test',
#  'Amitabh/doc-classification',
#  'Amro-Kamal/gpt',
#  'Amrrs/indian-foods',
#  'Amrrs/south-indian-foods',
#  'Amrrs/wav2vec2-large-xlsr-53-tamil',
#  'Ana1315/A',
#  'Ana1315/ana',
#  'AnaRhisT/bert_sequence_cs_validation',
#  'Analufm/Ana',
#  'Anamika/autonlp-Feedback1-479512837',
#  'Anamika/autonlp-fa-473312409',
#  'Anders/itu-ams-summa',
#  'Andi/bert-tt-ner-1',
#  'Andranik/TestPytorchClassification',
#  'Andranik/TestQA2',
#  'Andranik/TestQaV1',
#  'AndreLiu1225/t5-news-summarizer',
#  'AndreLiu1225/t5-news',
#  'Andres2015/HiggingFaceTest',
#  'AndrewChar/model-QA-5-epoch-RU',
#  'AndrewMcDowell/wav2vec2-xls-r-1B-german',
#  'AndrewMcDowell/wav2vec2-xls-r-1b-arabic',
#  'AndrewMcDowell/wav2vec2-xls-r-1b-japanese-hiragana-katakana',
#  'AndrewMcDowell/wav2vec2-xls-r-300m-arabic',
#  'AndrewMcDowell/wav2vec2-xls-r-300m-german-de',
#  'AndrewMcDowell/wav2vec2-xls-r-300m-japanese',
#  'AndrewNLP/redditDepressionPropensityClassifiers',
#  'Andrey1989/bert-multilingual-finetuned-ner',
#  'Andrey1989/mbart-finetuned-en-to-kk',
#  'Andrey1989/mbert-finetuned-ner',
#  'Andrey1989/mbert-finetuned-ner_2',
#  'Andrey1989/mt5-small-finetuned-mlsum-es',
#  'Andrey1989/mt5-small-finetuned-mlsum-fr',
#  'Andrey78/my_model_nlp',
#  'Andrey78/my_nlp_test_model',
#  'Andrianos/bert-base-greek-punctuation-prediction-finetuned',
#  'Andrija/M-bert-NER',
#  'Andrija/RobertaFastBPE',
#  'Andrija/SRoBERTa-F',
#  'Andrija/SRoBERTa-L-NER',
#  'Andrija/SRoBERTa-L',
#  'Andrija/SRoBERTa-NER',
#  'Andrija/SRoBERTa-NLP',
#  'Andrija/SRoBERTa-XL-NER',
#  'Andrija/SRoBERTa-XL',
#  'Andrija/SRoBERTa-base-NER',
#  'Andrija/SRoBERTa-base',
#  'Andrija/SRoBERTa',
#  'Andrija/SRoBERTaFastBPE-2',
#  'Andrija/SRoBERTaFastBPE',
#  'Andry/111',
#  'Andry/1111',
#  'Andy1621/uniformer',
#  'AndyJ/clinicalBERT',
#  'AndyJ/prompt_finetune',
#  'AndyyyCai/bert-base-uncased-finetuned-copa',
#  'Ani123/Ani',
#  'Anirbanbhk/Hate-speech-Pretrained-movies',
#  'tensor-trek/distilbert-base-uncased-finetuned-emotion',
#  'Anji/roberta-base-squad2-finetuned-squad',
#  'Ankit-11/distilbert-base-uncased-finetuned-toxic',
#  'Ankitha/DialoGPT-small-harrypotter',
#  'Ankitha/DialoGPT-small-harrypottery',
#  'Ann2020/distilbert-base-uncased-finetuned-ner',
#  'Ann2020/model-finetuned-ner',
#  'Ann2020/rubert-base-cased-finetuned-ner',
#  'Ann2020/rubert-base-cased-sentence-finetuned-ner',
#  'Ann2020/rubert-base-cased-sentence-finetuned-ner_tags',
#  'AnnettJaeger/AnneJae',
#  'Anomic/DialoGPT-medium-loki',
#  'AnonARR/qqp-bert',
#  'Anonymous/ReasonBERT-BERT',
#  'Anonymous/ReasonBERT-RoBERTa',
#  'Anonymous/ReasonBERT-TAPAS',
#  'Anonymous0230/model_name',
#  'AnonymousNLP/pretrained-model-1',
#  'AnonymousNLP/pretrained-model-2',
#  'AnonymousSub/AR_EManuals-BERT',
#  'AnonymousSub/AR_EManuals-RoBERTa',
#  'AnonymousSub/AR_SDR_HF_model_base',
#  'AnonymousSub/AR_bert-base-uncased',
#  'AnonymousSub/AR_cline',
#  'AnonymousSub/AR_consert',
#  'AnonymousSub/AR_declutr',
#  'AnonymousSub/AR_rule_based_bert_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_hier_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_only_classfn_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_only_classfn_twostage_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_bert_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_bert_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_bert_triplet_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_hier_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_hier_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_hier_triplet_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_only_classfn_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_only_classfn_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_only_classfn_twostage_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_only_classfn_twostage_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_twostage_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_twostage_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_twostagetriplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_twostagetriplet_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_roberta_twostagetriplet_hier_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_roberta_twostagetriplet_hier_epochs_1_shard_10',
#  'AnonymousSub/AR_rule_based_twostage_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_twostagequadruplet_hier_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_twostagetriplet_epochs_1_shard_1',
#  'AnonymousSub/AR_rule_based_twostagetriplet_hier_epochs_1_shard_1',
#  'AnonymousSub/AR_specter',
#  'AnonymousSub/EManuals_BERT_copy',
#  'AnonymousSub/EManuals_BERT_copy_wikiqa',
#  'AnonymousSub/EManuals_BERT_squad2.0',
#  'AnonymousSub/EManuals_RoBERTa_squad2.0',
#  'AnonymousSub/EManuals_RoBERTa_wikiqa',
#  'AnonymousSub/SDR_HF_model_base',
#  'AnonymousSub/SR_EManuals-BERT',
#  'AnonymousSub/SR_EManuals-RoBERTa',
#  'AnonymousSub/SR_SDR_HF_model_base',
#  'AnonymousSub/SR_bert-base-uncased',
#  'AnonymousSub/SR_cline',
#  'AnonymousSub/SR_consert',
#  'AnonymousSub/SR_declutr',
#  'AnonymousSub/SR_rule_based_bert_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_hier_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_only_classfn_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_only_classfn_twostage_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_bert_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_bert_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_bert_triplet_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_hier_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_hier_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_hier_triplet_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_hier_triplet_epochs_1_shard_1_wikiqa_copy',
#  'AnonymousSub/SR_rule_based_roberta_only_classfn_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_only_classfn_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_only_classfn_twostage_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_only_classfn_twostage_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_twostage_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_twostage_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_twostagetriplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_twostagetriplet_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_roberta_twostagetriplet_hier_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_roberta_twostagetriplet_hier_epochs_1_shard_10',
#  'AnonymousSub/SR_rule_based_twostage_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_twostagequadruplet_hier_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_twostagetriplet_epochs_1_shard_1',
#  'AnonymousSub/SR_rule_based_twostagetriplet_hier_epochs_1_shard_1',
#  'AnonymousSub/SR_specter',
#  'AnonymousSub/SciFive_pubmedqa_question_generation',
#  'AnonymousSub/T5_pubmedqa_question_generation',
#  'AnonymousSub/bert-base-uncased_squad2.0',
#  'AnonymousSub/bert-base-uncased_wikiqa',
#  'AnonymousSub/bert_hier_diff_equal_wts_epochs_1_shard_1',
#  'AnonymousSub/bert_hier_diff_equal_wts_epochs_1_shard_10',
#  'AnonymousSub/bert_mean_diff_epochs_1_shard_1',
#  'AnonymousSub/bert_mean_diff_epochs_1_shard_10',
#  'AnonymousSub/bert_snips',
#  'AnonymousSub/bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/bert_triplet_epochs_1_shard_10',
#  'AnonymousSub/cline-emanuals-s10-AR',
#  'AnonymousSub/cline-emanuals-s10-SR',
#  'AnonymousSub/cline-emanuals-techqa',
#  'AnonymousSub/cline-papers-biomed-0.618',
#  'AnonymousSub/cline-papers-roberta-0.585',
#  'AnonymousSub/cline-s10-AR',
#  'AnonymousSub/cline-s10-SR',
#  'AnonymousSub/cline-techqa',
#  'AnonymousSub/cline',
#  'AnonymousSub/cline_emanuals',
#  'AnonymousSub/cline_squad2.0',
#  'AnonymousSub/cline_wikiqa',
#  'AnonymousSub/consert-emanuals-s10-SR',
#  'AnonymousSub/consert-s10-AR',
#  'AnonymousSub/consert-s10-SR',
#  'AnonymousSub/consert-techqa',
#  'AnonymousSub/declutr-biomed-roberta-papers',
#  'AnonymousSub/declutr-emanuals-s10-AR',
#  'AnonymousSub/declutr-emanuals-s10-SR',
#  'AnonymousSub/declutr-emanuals-techqa',
#  'AnonymousSub/declutr-model-emanuals',
#  'AnonymousSub/declutr-model',
#  'AnonymousSub/declutr-model_squad2.0',
#  'AnonymousSub/declutr-model_wikiqa',
#  'AnonymousSub/declutr-roberta-papers',
#  'AnonymousSub/declutr-s10-AR',
#  'AnonymousSub/declutr-s10-SR',
#  'AnonymousSub/declutr-techqa',
#  'AnonymousSub/dummy_1',
#  'AnonymousSub/dummy_2',
#  'AnonymousSub/dummy_2_parent',
#  'AnonymousSub/hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/hier_triplet_epochs_1_shard_10',
#  'AnonymousSub/roberta-base_squad2.0',
#  'AnonymousSub/roberta-base_wikiqa',
#  'AnonymousSub/rule_based_bert_hier_diff_equal_wts_epochs_1_shard_1',
#  'AnonymousSub/rule_based_bert_hier_diff_equal_wts_epochs_1_shard_10',
#  'AnonymousSub/rule_based_bert_mean_diff_epochs_1_shard_1',
#  'AnonymousSub/rule_based_bert_mean_diff_epochs_1_shard_10',
#  'AnonymousSub/rule_based_bert_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_bert_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_bert_quadruplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_bert_quadruplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_bert_triplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_bert_triplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_bert_triplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_bert_triplet_epochs_1_shard_1_wikiqa_copy',
#  'AnonymousSub/rule_based_hier_quadruplet_0.1_epochs_1_shard_1',
#  'AnonymousSub/rule_based_hier_quadruplet_0.1_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_hier_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_hier_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_hier_quadruplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_hier_quadruplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_hier_triplet_0.1_epochs_1_shard_1',
#  'AnonymousSub/rule_based_hier_triplet_0.1_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_hier_triplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_hier_triplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_hier_triplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_hier_triplet_epochs_1_shard_1_wikiqa_copy',
#  'AnonymousSub/rule_based_only_classfn_epochs_1_shard_1',
#  'AnonymousSub/rule_based_only_classfn_epochs_1_shard_10',
#  'AnonymousSub/rule_based_only_classfn_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_only_classfn_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_only_classfn_twostage_epochs_1_shard_1',
#  'AnonymousSub/rule_based_only_classfn_twostage_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_bert_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_bert_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_bert_quadruplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_bert_quadruplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_bert_triplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_bert_triplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_bert_triplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_bert_triplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_bert_triplet_epochs_1_shard_1_wikiqa_copy',
#  'AnonymousSub/rule_based_roberta_hier_quadruplet_0.1_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_hier_quadruplet_0.1_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_hier_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_hier_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_hier_quadruplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_hier_quadruplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_hier_triplet_0.1_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_hier_triplet_0.1_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_hier_triplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_hier_triplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_hier_triplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_hier_triplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_hier_triplet_epochs_1_shard_1_wikiqa_copy',
#  'AnonymousSub/rule_based_roberta_only_classfn_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_only_classfn_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_only_classfn_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_only_classfn_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_only_classfn_twostage_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_only_classfn_twostage_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_only_classfn_twostage_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_only_classfn_twostage_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_twostage_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_twostage_quadruplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_twostage_quadruplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_twostage_quadruplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_twostagequadruplet_hier_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_hier_epochs_1_shard_1',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_hier_epochs_1_shard_10',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_hier_epochs_1_shard_1_squad2.0',
#  'AnonymousSub/rule_based_roberta_twostagetriplet_hier_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_twostage_quadruplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_twostage_quadruplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_twostagequadruplet_hier_epochs_1_shard_1',
#  'AnonymousSub/rule_based_twostagequadruplet_hier_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_twostagetriplet_epochs_1_shard_1',
#  'AnonymousSub/rule_based_twostagetriplet_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/rule_based_twostagetriplet_hier_epochs_1_shard_1',
#  'AnonymousSub/rule_based_twostagetriplet_hier_epochs_1_shard_1_wikiqa',
#  'AnonymousSub/specter-bert-model',
#  'AnonymousSub/specter-bert-model_copy',
#  'AnonymousSub/specter-bert-model_copy_wikiqa',
#  'AnonymousSub/specter-bert-model_squad2.0',
#  'AnonymousSub/specter-emanuals-model',
#  'AnonymousSub/unsup-consert-base',
#  'AnonymousSub/unsup-consert-base_copy',
#  'AnonymousSub/unsup-consert-base_copy_wikiqa',
#  'AnonymousSub/unsup-consert-base_squad2.0',
#  'AnonymousSub/unsup-consert-emanuals',
#  'AnonymousSub/unsup-consert-papers-bert',
#  'AnonymousSub/unsup-consert-papers',
#  'AnonymousSubmission/pretrained-model-1',
#  'Anonymreign/savagebeta',
#  'Anorak/nirvana',
#  'AnthonyNelson/DialoGPT-small-ricksanchez',
#  'Anthos23/FS-distilroberta-fine-tuned',
#  'Anthos23/distilbert-base-uncased-finetuned-sst2',
#  'Anthos23/my-awesome-model',
#  'Anthos23/sentiment-roberta-large-english-finetuned-sentiment-analysis',
#  'Anthos23/test_trainer',
#  'AntonClaesson/finetuning_test',
#  'AntonClaesson/movie-plot-generator',
#  'Antony/mint_model',
#  'Anubhav23/IndianlegalBert',
#  'Anubhav23/indianlegal',
#  'Anubhav23/model_name',
#  'Anupam/QuestionClassifier',
#  'Apisate/DialoGPT-small-jordan',
#  'Apisate/Discord-Ai-Bot',
#  'Aplinxy9plin/toxic-detection-rus',
#  'Apoorva/k2t-test',
#  'Appolo/TestModel',
#  'ArBert/albert-base-v2-finetuned-ner-agglo-twitter',
#  'ArBert/albert-base-v2-finetuned-ner-agglo',
#  'ArBert/albert-base-v2-finetuned-ner-gmm-twitter',
#  'ArBert/albert-base-v2-finetuned-ner-gmm',
#  'ArBert/albert-base-v2-finetuned-ner-kmeans-twitter',
#  'ArBert/albert-base-v2-finetuned-ner-kmeans',
#  'ArBert/albert-base-v2-finetuned-ner',
#  'ArBert/bert-base-uncased-finetuned-ner-agglo',
#  'ArBert/bert-base-uncased-finetuned-ner-gmm',
#  'ArBert/bert-base-uncased-finetuned-ner-kmeans-twitter',
#  'ArBert/bert-base-uncased-finetuned-ner-kmeans',
#  'ArBert/bert-base-uncased-finetuned-ner',
#  'ArBert/roberta-base-finetuned-ner-agglo-twitter',
#  'ArBert/roberta-base-finetuned-ner-agglo',
#  'ArBert/roberta-base-finetuned-ner-gmm-twitter',
#  'ArBert/roberta-base-finetuned-ner-gmm',
#  'ArBert/roberta-base-finetuned-ner-kmeans-twitter',
#  'ArBert/roberta-base-finetuned-ner-kmeans',
#  'ArBert/roberta-base-finetuned-ner',
#  'ArJakusz/DialoGPT-small-stark',
#  'ArJakusz/DialoGPT-small-starky',
#  'Araby/Arabic-TTS',
#  'Aracatto/Catto',
#  'Araf/Ummah',
#  'AragornII/DialoGPT-small-harrypotter',
#  'Aran/DialoGPT-medium-harrypotter',
#  'Aran/DialoGPT-small-harrypotter',
#  'ArashEsk95/bert-base-uncased-finetuned-cola',
#  'ArashEsk95/bert-base-uncased-finetuned-sst2',
#  'ArashEsk95/bert-base-uncased-finetuned-stsb',
#  'Aravinth/test',
#  'ArcQ/gpt-experiments',
#  'Arcanos/1',
#  'Archie/myProject',
#  'Arcktosh/DialoGPT-small-rick',
#  'ArenaGrenade/char-cnn',
#  'Arghyad/Loki_small',
#  'AriakimTaiyo/DialoGPT-cultured-Kumiko',
#  'AriakimTaiyo/DialoGPT-medium-Kumiko',
#  'AriakimTaiyo/DialoGPT-revised-Kumiko',
#  'AriakimTaiyo/DialoGPT-small-Kumiko',
#  'AriakimTaiyo/DialoGPT-small-Rikka',
#  'AriakimTaiyo/kumiko',
#  'Aries/T5_question_answering',
#  'Aries/T5_question_generation',
#  'Arina/Erine',
#  'ArjunKadya/HuggingFace',
#  'Arkadiusz/Test-model',
#  'asaakyan/mbart-poetic-all',
#  'ArnaudPannatier/MLPMixer',
#  'Arnold/common_voiceha',
#  'Arnold/wav2vec2-hausa-demo-colab',
#  'Arnold/wav2vec2-hausa2-demo-colab',
#  'Arnold/wav2vec2-large-xlsr-hausa2-demo-colab',
#  'Arnold/wav2vec2-large-xlsr-turkish-demo-colab',
#  'Aron/distilbert-base-uncased-finetuned-emotion',
#  'ArpanZS/debug_squad',
#  'ArpanZS/search_model',
#  'Arpita/opus-mt-en-ro-finetuned-syn-to-react',
#  'Arpita/opus-mt-en-ro-finetuned-synthon-to-reactant',
#  'ArseniyBolotin/bert-multi-PAD-ner',
#  'ArshdeepSekhon050/DialoGPT-medium-RickAndMorty',
#  'ArtemisZealot/DialoGTP-small-Qkarin',
#  'ArthurBaia/bert-base-portuguese-cased-finetuned-squad',
#  'ArthurcJP/DialoGPT-small-YODA',
#  'Aruden/DialoGPT-medium-harrypotterall',
#  'ielabgroup/BiTAG-t5-large',
#  'AryanLala/autonlp-Scientific_Title_Generator-34558227',
#  'AshLukass/AshLukass',
#  'Ashagi/Ashvx',
#  'AshiNLP/Bert_model',
#  'Ashim/dga-transformer',
#  'Ashkanmh/bert-base-parsbert-uncased-finetuned',
#  'Ashl3y/model_name',
#  'Ashok/my-new-tokenizer',
#  'Aspect11/DialoGPT-Medium-LiSBot',
#  'Asuramaru/DialoGPT-small-rintohsaka',
#  'At3ee/wav2vec2-base-timit-demo-colab',
#  'Atampy26/GPT-Glacier',
#  'Atarax/rick',
#  'Atchuth/DialoGPT-small-MBOT',
#  'Atchuth/DialoGPT-small-MichaelBot',
#  'Atchuth/MBOT',
#  'Ateeb/EmotionDetector',
#  'Ateeb/FullEmotionDetector',
#  'Ateeb/QA',
#  'Ateeb/SquadQA',
#  'Ateeb/asd',
#  'Atiqah/Atiqah',
#  'Atlasky/Turkish-Negator',
#  'Atlasky/turkish-negator-nn',
#  'Augustab/distilbert-base-uncased-finetuned-cola',
#  'Augustvember/WOKKAWOKKA',
#  'Augustvember/WokkaBot',
#  'Augustvember/WokkaBot2',
#  'Augustvember/WokkaBot3',
#  'Augustvember/WokkaBot4',
#  'Augustvember/WokkaBot5',
#  'Augustvember/WokkaBot6',
#  'Augustvember/WokkaBot7',
#  'Augustvember/WokkaBot8',
#  'Augustvember/WokkaBot9',
#  'Augustvember/WokkaBot99',
#  'Augustvember/WokkaBotF',
#  'Augustvember/test',
#  'Augustvember/wokka',
#  'Augustvember/wokka2',
#  'Augustvember/wokka4',
#  'Augustvember/wokka5',
#  'Augustvember/wokkabottest2',
#  'Augustvember/your-model-name',
#  'Aurora/asdawd',
#  'Aurora/community.afpglobal',
#  'AvatarXD/DialoGPT-medium-Blitzo',
#  'Aviora/news2vec',
#  'Aviora/phobert-ner',
#  'Awsaf/DialoGPT-medium-eren',
#  'Awsaf/large-eren',
#  'Axcel/DialoGPT-small-rick',
#  ...]

# %%
search_name = "google-bert/bert-base-cased"
index = df.index[df['id'] == search_name].item()
folder_name = search_name.split('/')[1]

# %% [markdown]
# ### 문서 수집

# %%
url = f'https://huggingface.co/{search_name}'
response = requests.get(url, timeout=2)
response.raise_for_status()  # 요청 실패 시 예외 발생

soup = BeautifulSoup(response.text, 'html.parser')

os.makedirs(f"./models/{folder_name}", exist_ok=True)  # 폴더가 이미 존재해도 오류 발생하지 않음
model_card_path = os.path.join('models', folder_name, 'page.txt')

if soup:
    with open(model_card_path, 'w', encoding='utf-8') as file:
        file.write(str(soup))

# %% [markdown]
# ### ISO code 수집

# %%
url = 'https://huggingface.co/languages'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

table_card = soup.find_all('table')

language_iso_code = []
rows = soup.find_all('tr')

for row in tqdm(rows[1:], desc="Processing rows"):
    iso_code_td = row.find_all('td')[1]
    iso_code = iso_code_td.text.strip()
    language_iso_code.append(iso_code)
# Out:
# Processing rows: 100%|██████████| 4680/4680 [00:00<00:00, 43454.86it/s]

# %%
libraries_list1 = [
    "transformers", "sentence-transformers", "keras", "adapter-transformers", "speechbrain",
    "espnet", "spacy", "fasttext", "asteroid", "generic", "ml-agents", "stable-baselines3",
    "pytorch", "flair", "allennlp", "fairseq", "k2", "tensorflowtts", "fastai", "opennmt",
    "timm", "sklearn", "paddlenlp", "superb", "doctr", "mindspore", "pytorch-ie", "pyannote-audio",
    "pysentimiento", "stanza", "PyTorch", "nemo", "txtai", "fastpitch", "pytorch-lightning",
    "PyTorch Lightning", "diffusers", "sample-factory", "k2-sherpa", "JoeyNMT", "FastAI",
    "stable-diffusion", "tfhub", "pythae", "open_clip", "mlconsole", "cleanrl", "setfit",
    "span-marker", "Doc-UFCN", "fastMONAI", "EveryDream", "kenlm", "BERT", "paddle_nlp",
    "rl-algo-impls", "PyLaia", "lucidrains/gated-state-spaces-pytorch", "TTS", "yolov5",
    "onnx", "yolov6detect", "ultralytics", "skrl", "yolor", "xpmir", "tensorflow", "peft",
    "scvi-tools", "hezar", "ppdiffusers", "mbrl-lib", "aster", "gpt-neox", "archai", "deep-rl-course",
    "Spacy", "ggml", "ctranslate2", "pcdet", "KerasCV Stable Diffusion in Diffusers", "tf",
    "tdc", "transformers.js", "PaddleNLP", "Transformers", "parking-env", "bertopic", "zeroshot_classifier",
    "ctransformers", "KerasNLP", "yolo", "safetensors", "safe-rlhf", "torch", "minetest-baselines",
    "audiocraft", "Core ML", "easydel", "wildlife-datasets", "monai", "fairseq2", "mlc", "Pytorch",
    "output-small", "braindecode", "coqui", "optimum_neuronx", "yasep", "bitsandbytes, transformers, peft, accelerate, bitsandbytes, datasets, deepspeed, trl",
    "htrflow_core", "xmen", "CTranslate2", "muzero-general", "pufferlib", "pytorch_geometric",
    "scikit-learn", "textgen", "peft - PEFT 0.5.0", "mlx", "DanishFungi", "asteroid1111111111111111111111111111111",
    "pruna-engine", "llama.cpp", "seamless_communication", "Spacy Explosion", "femr", "https://github.com/monet-joe/Piano-Classification",
    "clmbr", "xtuner", "fire-and-smoke", "TraceBERT", "Megatron-LM", "mlx-llm", "RAGatouille",
    "clinicadl", "unity-sentis", "ExLlamaV2", "tokenizers", "aim", "Bunkatopics",
    "transformers, Unsloth, Peft, trl, accelerate, bitsandbytes", "Flax", "ml-aim", "hierarchy-transformers",
    "Keras", "peft,sfttrainer", "whisperkit", "nanotron", "trl", "LLaVA", "transformers, peft, torch",
    "OpenVINO", "transformers, peft", "fasttext, bert", "tensorflow, keras", "metavoice", "gguf",
    "https://github.com/ICE-PIXIU", "colbert-ai", "gliner", "sglang", "non", "mlx-image",
    "GGUF", "gemma.cpp", "gemma_torch", "keras-nlp", "jax", "atommic", "mobileclip",
    "transformers(OpenNMT)", "v-jepa", "Transformers PHP", "whisper", "grok", "clot",
    "transformers, pe", "keras3", "UniFormer", "ml-4m", "fla", "UniFormerV2",
    "UniDepth", "voicecraft", "michelangelo", "openlm", "recurrentgemma", "tflite",
    "ditto", "PyTorchModelHubMixin-template", "Haystack", "elm", "litgpt, transformers",
    "dust3r", "rasa", "BiRefNet", "en-tts", "my-meta-test", "Gen AI", "zho-tts",
    "transformers accelerate bitsandbytes", "pyannote", "llama-cpp", "torchvision",
    "timesfm", "torchtune", "big_vision", "llamafile", "light-embed", "transformers, PyTorch",
    "edsnlp", "ultralyticsplus", "unsloth", "gptq", "chat_tts", "delphi", "burial_mounds",
    "fugent", "Nvidia Nemo", "segmentation-models-pytorch", "executorch", "multimolecule"
]

libraries_list2 = [
    "PyTorch", "TensorFlow", "JAX", "Transformers", "Safetensors", "TensorBoard", "PEFT",
    "Diffusers", "GGUF", "stable-baselines3", "ONNX", "ml-agents", "sentence-transformers",
    "Keras", "Adapters", "setfit", "timm", "sample-factory", "Flair", "Transformers.js",
    "MLX", "spaCy", "fastai", "ESPnet", "Core ML", "OpenVINO", "NeMo", "Joblib", "Rust",
    "BERTopic", "TF Lite", "fastText", "OpenCLIP", "Scikit-learn", "PaddlePaddle", "speechbrain",
    "Fairseq", "Graphcore", "Asteroid", "AllenNLP", "Stanza", "llamafile", "SpanMarker",
    "paddlenlp", "Habana", "pyannote.audio", "pythae", "unity-sentis"
]

# 첫 글자가 대문자인 경우와 소문자인 경우를 모두 포함한 라이브러리 리스트 생성
def create_case_insensitive_list(libraries):
    case_insensitive_list = set()
    for lib in libraries:
        case_insensitive_list.add(lib.lower())
        case_insensitive_list.add(lib.capitalize())
    return case_insensitive_list

normalized_libraries_list1 = set(lib.lower().replace('-', ' ') for lib in libraries_list1)
normalized_libraries_list2 = create_case_insensitive_list(libraries_list2)

# 새로운 컬럼 생성
df['library_name'] = ''
df['language'] = ''

# Process libraries for the specific row
row = df.loc[index]

# %%
row
# Out:
# id                                     google-bert/bert-base-cased
# author                                                 google-bert
# created_at                               2022-03-02 23:29:04+00:00
# last_modified                            2024-02-19 11:02:26+00:00
# private                                                      False
# gated                                                        False
# disabled                                                       NaN
# downloads                                                  4819762
# likes                                                          231
# library_name
# tags             ['transformers', 'pytorch', 'tf', 'jax', 'safe...
# pipeline_tag                                             fill-mask
# arxiv                                             arxiv:1810.04805
# dataset                                          dataset:wikipedia
# region                                                   region:us
# license                                         license:apache-2.0
# language
# Name: 9, dtype: object

# %%
# Process libraries for the specific row
row = df.loc[index]  # Select the row by index

tags = row['tags']

# Check if 'tags' is a string and needs to be evaluated
if isinstance(tags, str):
    tags = ast.literal_eval(tags)

# Extract libraries from the tags
libraries = [tag for tag in tags if tag.lower().replace('-', ' ') in normalized_libraries_list1 or tag.lower().replace('-', ' ') in normalized_libraries_list2]
df.at[index, 'library_name'] = ', '.join(libraries)

# Update 'tags' by removing libraries
tags = [tag for tag in tags if tag not in libraries]
df.at[index, 'tags'] = str(tags)

# Process languages for the specific row
languages = [tag for tag in tags if tag in language_iso_code]
df.at[index, 'language'] = ', '.join(languages)

# Update 'tags' by removing languages
tags = [tag for tag in tags if tag not in languages]
df.at[index, 'tags'] = str(tags)

# 'tags' 열을 리스트로 변환
tags = ast.literal_eval(df.at[index, 'tags'])  # Ensure 'tags' column is a list

# Function to remove duplicates based on specific columns
compare_columns = [
    'id', 'author', 'created_at', 'last_modified', 'private', 'gated', 'disabled', 'downloads', 'likes', 'library_name', 'pipeline_tag', 'arxiv', 'dataset', 'region'
]

def remove_duplicates(tags, compare_columns, row):
    for column in compare_columns:
        value = row[column]
        if isinstance(value, str) and value in tags:
            tags.remove(value)
    return tags

# Remove duplicates for this row
tags = remove_duplicates(tags, compare_columns, row)

# Update 'tags' for the current row
df.at[index, 'tags'] = str(tags)

# %%
loc_df = df.loc[index]

# %%
loc_df
# Out:
# id                                     google-bert/bert-base-cased
# author                                                 google-bert
# created_at                               2022-03-02 23:29:04+00:00
# last_modified                            2024-02-19 11:02:26+00:00
# private                                                      False
# gated                                                        False
# disabled                                                       NaN
# downloads                                                  4819762
# likes                                                          231
# library_name     transformers, pytorch, tf, jax, safetensors, bert
# tags             ['exbert', 'autotrain_compatible', 'endpoints_...
# pipeline_tag                                             fill-mask
# arxiv                                             arxiv:1810.04805
# dataset                                          dataset:wikipedia
# region                                                   region:us
# license                                         license:apache-2.0
# language                                                        en
# Name: 9, dtype: object

# %%
# Process libraries for the specific row
tags = row['tags']

# Check if 'tags' is a string and needs to be evaluated
if isinstance(tags, str):
    tags = ast.literal_eval(tags)

# Extract libraries from the tags
libraries = [tag for tag in tags if tag.lower().replace('-', ' ') in normalized_libraries_list1 or tag.lower().replace('-', ' ') in normalized_libraries_list2]
df.at[index, 'library_name'] = ', '.join(libraries)

# Update 'tags' by removing libraries
tags = [tag for tag in tags if tag not in libraries]
df.at[index, 'tags'] = str(tags)

# Process languages for the specific row
languages = [tag for tag in tags if tag in language_iso_code]
df.at[index, 'language'] = ', '.join(languages)

# Update 'tags' by removing languages
tags = [tag for tag in tags if tag not in languages]
df.at[index, 'tags'] = str(tags)

# %%
# 첫 번째 처리
for ind, row in tqdm(df.iterrows(), desc="Processing libraries", total=len(df)):
    tags = ast.literal_eval(row['tags'])
    libraries = [tag for tag in tags if tag.lower().replace('-', ' ') in normalized_libraries_list1 or tag.lower().replace('-', ' ') in normalized_libraries_list2]
    df.at[ind, 'library_name'] = ', '.join(libraries)
    row['tags'] = [tag for tag in tags if tag not in libraries]
    df.at[ind,'tags'] = str(row['tags'])

# 두 번째 처리
for ind, row in tqdm(df.iterrows(), desc="Processing languages", total=len(df)):
    tags = ast.literal_eval(row['tags'])
    languages = [tag for tag in tags if tag in language_iso_code]
    df.at[ind, 'language'] = ', '.join(languages)
    row['tags'] = [tag for tag in tags if tag not in languages]
    df.at[ind,'tags'] = str(row['tags'])

# %%
# 'tags' 열을 리스트로 변환
df['tags'] = df['tags'].apply(ast.literal_eval)

compare_columns = [
    'id', 'author', 'created_at', 'last_modified', 'private', 'gated', 'disabled', 'downloads', 'likes','library_name', 'pipeline_tag', 'arxiv', 'dataset', 'region'
]

def remove_duplicates(tags, compare_columns, row):
    for column in compare_columns:
        value = row[column]
        if isinstance(value, str) and value in tags:
            tags.remove(value)
    return tags

# tqdm을 사용하여 전체 DataFrame에 대한 진행 상황 표시
tqdm.pandas(desc="처리 중")

# apply 함수를 사용하여 각 행에 대해 중복 제거
df['tags'] = df.progress_apply(lambda row: remove_duplicates(row['tags'], compare_columns, row), axis=1)

# %%
loc_df['id']
# Out:
# 'albert/albert-base-v1'

# %%
model_name = loc_df['id'].split('/')[1]

# %%
loc_df
# Out:
# id                                     google-bert/bert-base-cased
# author                                                 google-bert
# created_at                               2022-03-02 23:29:04+00:00
# last_modified                            2024-02-19 11:02:26+00:00
# private                                                      False
# gated                                                        False
# disabled                                                       NaN
# downloads                                                  4819762
# likes                                                          231
# library_name     transformers, pytorch, tf, jax, safetensors, bert
# tags             ['exbert', 'autotrain_compatible', 'endpoints_...
# pipeline_tag                                             fill-mask
# arxiv                                             arxiv:1810.04805
# dataset                                          dataset:wikipedia
# region                                                   region:us
# license                                         license:apache-2.0
# language                                                        en
# Name: 9, dtype: object

# %%
model_name = loc_df['id'].split('/')[1]
row_dict = loc_df.to_dict()  # row_dict를 JSON 파일로 저장

# NaN 값을 None으로 변환
for key, value in row_dict.items():
    if isinstance(value, float) and np.isnan(value):
        row_dict[key] = None

# JSON 파일로 저장
with open(f'./models/{model_name}/Abstract.json', 'w', encoding='utf-8') as json_file:
    json.dump(row_dict, json_file, ensure_ascii=False, indent=4)

# %% [markdown]
# ### 컨텐츠 수집

# %%
file_path = os.path.join('models', folder_name, 'page.txt')
    
with open(file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# %%
soup = BeautifulSoup(html_content, 'html.parser')
model_card = soup.find('div', class_='model-card-content')

# %%
section_file_path = os.path.join('models', folder_name, 'Contents.txt')

with open(section_file_path, 'w', encoding='utf-8') as section_file:
    section_file.write(str(model_card))

# %% [markdown]
# ### 사이드 수집

# %%
side_section = soup.find('section', class_="pt-8 border-gray-100 md:col-span-5 pt-6 md:pb-24 md:pl-6 md:border-l order-first md:order-none")

# %%
section_file_path = os.path.join('models', folder_name, f"Side.txt")
            
with open(section_file_path, 'w', encoding='utf-8') as section_file:
    section_file.write(str(side_section))

# %% [markdown]
# ### 사이드 딕셔너리(데이터세트, 어댑터, 파인튜닝, 병합, 양자화)

# %%
file_path = os.path.join('models', model_name, 'Side.txt')

with open(file_path, 'r', encoding='utf-8') as file:
    side_content = file.read()

soup = BeautifulSoup(side_content, 'html.parser')

def get_model_info(selector): # Helper 함수: 모델 수와 링크를 추출
        element = soup.select_one(f'a[href*="{selector}"]')
        if element:
            models_text = element.text
            model_count = int(models_text.split()[0])  # "42 models"에서 42 추출
            model_link = element['href']
        else:
            model_count = 0
            model_link = ""
        return model_count, model_link

adapters_count, adapters_link = get_model_info("base_model:adapter") # Adapters, Finetunes, Merge, Quantized 모델 수와 링크 추출
finetune_count, finetune_link = get_model_info("base_model:finetune")
merge_count, merge_link = get_model_info("base_model:merge")
quantized_count, quantized_link = get_model_info("base_model:quantized")

dataset_elements = soup.select('h4.text-md.truncate.font-mono') # 데이터세트 추출 (여러 개일 경우 모두 수집)
dataset_names = [element.text.strip() for element in dataset_elements]  # 데이터세트 이름 리스트로 저장

data = { # 딕셔너리 형태로 반환
    "Model Name": model_name,
    "Adapter Model Count": adapters_count,
    "Adapter Link": adapters_link,
    "Finetune Model Count": finetune_count,
    "Finetune Link": finetune_link,
    "Merge Model Count": merge_count,
    "Merge Link": merge_link,
    "Quantized Model Count": quantized_count,
    "Quantized Link": quantized_link,
    "Dataset Names": dataset_names  # 여러 개의 데이터세트 리스트로 반환
}

# %%
if isinstance(dataset_names, str): # 문자열로 된 리스트를 실제 리스트로 변환
    dataset_names = eval(dataset_names)

# %%
os.makedirs(f'./models/{model_name}/derived/dataset', exist_ok=True)

output_directory = f'./models/{model_name}/derived/dataset'
safe_file_name = f"{model_name}.json" # 파일명에 불가능한 문자가 포함되어 있는 경우 처리 (예: 슬래시 '/' 등)
file_path = os.path.join(output_directory, safe_file_name)

dataset = { # 파일에 저장할 내용
    'dataset': dataset_names
}

with open(file_path, 'w', encoding='utf-8') as f: # JSON 파일로 저장
    json.dump(dataset, f, indent=4, ensure_ascii=False)

# %%
os.makedirs(f'./models/{model_name}/derived', exist_ok=True)

# %%
os.makedirs(f'./models/{model_name}/derived/adapter', exist_ok=True)

# %%
def scrape_huggingface_models(data, model_name_list):
    """
    Hugging Face의 다양한 모델(어댑터, 파인튜닝, 병합, 양자화) 정보를 스크래핑하는 함수
    
    :param data: 모델 관련 정보를 포함한 딕셔너리
    """
    model_types = {
        "Adapter": ("Adapter Model Count", "Adapter Link"),
        "Finetune": ("Finetune Model Count", "Finetune Link"),
        "Merge": ("Merge Model Count", "Merge Link"),
        "Quantized": ("Quantized Model Count", "Quantized Link")
    }
    
    for model_type, (count_key, link_key) in model_types.items():
        # for i in tqdm(range(data[count_key]), desc=f"Processing {model_type} Models"):
        file_name = data['Model Name']
        page_number = math.ceil(data[count_key] / 30)
        for page in tqdm(range(page_number), desc=f"Processing pages for {file_name} ({model_type})"):
            try:
                base_url = f"https://huggingface.co/models?other=base_model:{model_type.lower()}:{model_name_list}&p={page}&sort=trending"
                response = requests.get(base_url, timeout=2)
                response.raise_for_status()
                
                soup = BeautifulSoup(response.text, 'html.parser')
                section_content = soup.find(
                    'section', class_='pt-8 border-gray-100 col-span-full lg:col-span-6 xl:col-span-7 pb-12'
                )
                
                if section_content:
                    output_dir = f'./models/{file_name}/derived/{model_type.lower()}/'
                    os.makedirs(output_dir, exist_ok=True)
                    
                    with open(f'{output_dir}{file_name}_{page}page.txt', 'w', encoding='utf-8') as file:
                        file.write(str(section_content))
            
            except Exception as e:
                print(f"Error processing {file_name} ({model_type}) on page {page}: {e}")
                
            time.sleep(random.uniform(0.5, 1.5))

# %%
scrape_huggingface_models(data, search_name)
# Out:
# Processing pages for bert-base-cased (Adapter): 100%|██████████| 2/2 [00:03<00:00,  1.93s/it]
# Processing pages for bert-base-cased (Finetune):  43%|████▎     | 31/72 [01:02<01:22,  2.02s/it]
# Error processing bert-base-cased (Finetune) on page 31: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=2)
# Processing pages for bert-base-cased (Finetune): 100%|██████████| 72/72 [02:29<00:00,  2.07s/it]
# Processing pages for bert-base-cased (Merge): 0it [00:00, ?it/s]
# Processing pages for bert-base-cased (Quantized): 100%|██████████| 1/1 [00:01<00:00,  1.65s/it]

# %%
# Model folder names based on the model
output_dirs = ['adapter', 'finetune', 'merge', 'quantized']

model_folder = {
    'adapter': 'adapter_instance',
    'finetune': 'finetune_instance',
    'merge': 'merge_instance',
    'quantized': 'quantized_instance'
}

# Iterate over the output directories and print the folder paths
for output_dir in output_dirs:
    folder_path = os.path.join('models', model_name, 'derived', output_dir)
    print(f"Processing directory: {folder_path}")

    # Check if the directory exists, if not, skip it
    if not os.path.exists(folder_path):
        print(f"Skipping: {folder_path} (Directory not found)")
        continue  # Skip to the next folder

    # Directory to search for files
    directory = folder_path

    # File pattern dictionary to store model name and page numbers
    file_pattern_data = {}

    # Get all files in the directory
    for filename in os.listdir(directory):
        if filename.endswith('page.txt'):
            # Extract model name and page number from the filename
            model_name_part, page_part = filename.rsplit('_', 1)
            page_num_part = page_part.replace('page.txt', '')

            if page_num_part.isdigit():  # Check if page number is valid
                page_num = int(page_num_part)
                if model_name_part not in file_pattern_data:
                    file_pattern_data[model_name_part] = []
                file_pattern_data[model_name_part].append(page_num)

    # Collect model data by page numbers
    for model_name, page_numbers in file_pattern_data.items():
        max_page_number = max(page_numbers)  # Find the max page number

        model_info = {
            output_dir: []
        }

        for page_num in range(0, max_page_number + 1):
            file_path = os.path.join(directory, f'{model_name}_{page_num}page.txt')

            if os.path.exists(file_path):
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read()  # Read the whole file content

                soup = BeautifulSoup(content, 'html.parser')

                # Find all articles in the content
                articles = soup.find_all('article', class_='overview-card-wrapper group/repo')

                for article in articles:
                    # Extract model name from the article
                    model_name_tag = article.find('h4', class_='text-md truncate font-mono text-black dark:group-hover/repo:text-yellow-500 group-hover/repo:text-indigo-600 text-smd')
                    model_name_extracted = model_name_tag.get_text(strip=True) if model_name_tag else None

                    model_info[output_dir].append(model_name_extracted)

                # Choose the correct folder from model_folder mapping
                target_folder = model_folder.get(output_dir)  # Get the folder name from model_folder mapping
                if target_folder:
                    # Create the target folder if it doesn't exist
                    os.makedirs(f'./models/{model_name}/derived/{target_folder}', exist_ok=True)
                    
                    # Save the model info to JSON in the corresponding folder
                    json_output_path = os.path.join(f'./models/{model_name}/derived/{target_folder}', f'{model_name}.json')
                    with open(json_output_path, "w") as json_file:
                        json.dump(model_info, json_file, indent=4)
                else:
                    print(f"Folder not found for {output_dir}")
            else:
                print(f"File not found: {file_path}")
# Out:
# Processing directory: models\bert-base-cased\derived\adapter
# Processing directory: models\bert-base-cased\derived\finetune
# File not found: models\bert-base-cased\derived\finetune\bert-base-cased_31page.txt
# Processing directory: models\bert-base-cased\derived\merge
# Skipping: models\bert-base-cased\derived\merge (Directory not found)
# Processing directory: models\bert-base-cased\derived\quantized

# %%
def merge_model_data(base_folder, instance_folders):
    data = {}
    
    for folder in instance_folders:
        instance_path = os.path.join(base_folder, folder)
        if not os.path.exists(instance_path):
            continue
        
        json_files = [f for f in os.listdir(instance_path) if f.endswith('.json')]
        
        for file in json_files:
            file_path = os.path.join(instance_path, file)
            with open(file_path, 'r', encoding='utf-8') as f:
                file_data = json.load(f)
                data.update(file_data)
    
    return data

base_folder = f'./models/{model_name}/derived'
instance_folders = ['adapter_instance', 'finetune_instance', 'quantized_instance', 'merge_instance', 'dataset']
model_side_data = merge_model_data(base_folder, instance_folders)

# %%
model_side_data
# Out:
# {'adapter': ['identrics/wasper_propaganda_detection_en',
#   'tomhodemon/query_encoder_lora_v1',
#   'tomhodemon/passage_encoder_lora_v1',
#   'tomhodemon/fever-query_encoder-lora-bsz16-77588-gradacc1',
#   'tomhodemon/fever_passage_encoder-lora-bsz16-77588-gradacc1',
#   'MaximTitarenkoUIT/reward_test_on_filtered_data_lora',
#   'MonkeyDdonut/aiVshuman_bert_2epochs',
#   'sumittyagi25/test_trainer',
#   'Rastael/bert-base-cased-sequence-classification',
#   'stanpony/ml_medical_diagnosis',
#   'EliasKD/LoRA-imdb-seq-cls',
#   'EliasKD/LoRA-my-dataset-seq-cls',
#   'MaggieZhang/test_trainer',
#   'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_irony',
#   'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_emotion',
#   'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_hate',
#   'rajevan123/STS-Lora-Fine-Tuning-Capstone-bert-testing-70-with-lower-r-mid',
#   'Jahanzeb1/BERT-TextClassification',
#   'dfoc99/bert-base-cased-finetuned-Astronomy_Thesaurus',
#   'stonedsmv/BERT-peft_LoRA',
#   'abhishekkumaribt/bert-lora',
#   'ElMad/luxuriant-squid-867',
#   'ElMad/capable-doe-250',
#   'ElMad/persistent-dog-343',
#   'ElMad/unequaled-ape-267',
#   'ElMad/bouncy-colt-342',
#   'Prasanna05/ner_lora_output',
#   'ElMad/grandiose-horse-172',
#   'ElMad/beautiful-worm-91',
#   'ElMad/marvelous-pug-454',
#   'ElMad/receptive-hog-274',
#   'ElMad/rogue-crane-540',
#   'ElMad/gaudy-hound-390',
#   'joshuaspear/bert-base-cased-finetuned-health-qa',
#   'Deban/output',
#   'katsuchi/results',
#   'katsuchi/bert-dair-ai-emotion',
#   'katsuchi/bert-dair-ai-emotion-testing'],
#  'finetune': ['Kushtrim/bert-base-cased-biomedical-ner',
#   'Zabihin/Symptom_to_Diagnosis',
#   'HUMADEX/polish_medical_ner',
#   'VolkanSimsir/ber-finetuned-ner',
#   'viswadarshan06/pd-bert',
#   'luheng/bert-finetuned-ner',
#   'tartuNLP/EstBERT',
#   'kamalkraj/bert-base-cased-ner-conll2003',
#   'dimboump/glue_sst_classifier',
#   'juancopi81/bert-finetuned-ner',
#   'juancopi81/course-bert-finetuned-squad',
#   'phamvanlinh143/bert-finetuned-ner',
#   'dsantistevan/bert-base-cased-bert-yoga-finetuned',
#   'nickprock/bert-finetuned-ner-ontonotes',
#   'jfcruz13/bert-finetuned-ner',
#   'noahgift/hf_fine_tune_hello_world',
#   'Asmit/bert-finetuned-squad',
#   'jtlicardo/bert-finetuned-bpmn',
#   'asifraza/results',
#   'jtlicardo/bpmn-information-extraction',
#   'zhengke/bert-finetuned-squad',
#   'jtlicardo/bpmn-information-extraction-v2',
#   'qfrodicio/bert-finetuned-gesture-prediction-21-classes',
#   'tomaarsen/span-marker-bert-base-fewnerd-fine-super',
#   'sooolee/bert-finetuned-squad-v1',
#   'Iiro/bert_reviews',
#   'TechnicalMoruJiii/bert-finetuned-squad',
#   'johnjose223/Bert_Squad',
#   'Shariar433/bert-finetuned-ner',
#   'sitthichokpaugchan/finetuned-bert',
#   'MUmairAB/bert-ner',
#   'insub/bert-finetuned-squad',
#   'imtiaz114/bert-finetuned-ner-baseline-1',
#   'slickdata/finetuned-Sentiment-classfication-BERT-model',
#   'elvis-d/elvis_bert_base',
#   'conorjudge/bert-finetuned-ner',
#   'chunwoolee0/bert-finetuned-ner',
#   'mulinski/bert-finetuned-squad',
#   'PhysHunter/bert-finetuned-squad',
#   'sarahflan/bert-finetuned-ner',
#   'Kerz/bbc',
#   'UholoDala/tweet_sentiments_analysis_bert',
#   'penscola/tweet_sentiments_analysis_bert',
#   'KingAsiedu/tweet_sentiments_analysis_bert',
#   'stefaniftime/bert-finetuned-ner-v2',
#   'Jedida/tweet_sentiments_analysis_bert',
#   'Yaopu/bert-finetuned-squad',
#   'ronyw7/BERT_PatentAbstract2IncomeGroup_2500',
#   'EricPeter/bert-finetuned-squad',
#   'badokorach/bert-finetuned-squad',
#   'youngsun05/bert-finetuned-squad',
#   'happyone/bert-finetuned-ner',
#   'VCool22/bert-finetuned-ner',
#   'Gikubu/Gikubu_bert_base',
#   'aman38649/bert-finetuned-ner',
#   'donskerclass/bert-finetuned-ner',
#   'tr-aravindan/bert-finetuned-ner',
#   'nickovchinnikov/bert-finetuned-ner',
#   'stefaniftime/bert-finetuned-squad',
#   'runningsnake/bert-finetuned-ner',
#   'badokorach/bert-base-cased-finetuned',
#   'shre-db/bert-finetuned-ner',
#   'jakobkruse/bert-finetuned-squad',
#   'cssupport/bert-finetuned-ner',
#   'autosyrup/bert',
#   'mundepankaj/bert-finetuned-ner',
#   'Joelt0/bert-finetuned-ner',
#   'fadliaulawi/bert-finetuned-squad',
#   'deepanshu30699/bert-finetuned-ner',
#   'Sambosis/bert-base-cased-finetuned-swag',
#   'YanJiangJerry/baseline_bert-base-cased_epoch3_batch4_lr2e-05_w0.01',
#   'danexl/bert-finetuned-ner',
#   'ShynBui/s1',
#   'ShynBui/s2',
#   'ShynBui/s3',
#   'sgugger/push-to-hub-test-2',
#   'ShynBui/s4',
#   'ShynBui/s5',
#   'ShynBui/s7',
#   'ShynBui/s8',
#   'ShynBui/s9',
#   'ShynBui/s10',
#   'ShynBui/s11',
#   'ShynBui/s13',
#   'ShynBui/s14',
#   'ShynBui/s15',
#   'ShynBui/s16',
#   'ShynBui/s17',
#   'ShynBui/s19',
#   'ShynBui/s20',
#   'ShynBui/s21',
#   'ShynBui/s23',
#   'ShynBui/s25',
#   'ShynBui/s28',
#   'chunwoolee0/bert-finetuned-squad',
#   'y-taki/my-model',
#   'y-taki/my-model-0808',
#   'adon81/bert-finetuned-ner',
#   'Shafaet02/bert-fine-tuned-cola',
#   'Francesco-A/bert-finetuned-ner',
#   'sachin2000keshav/bert-finetuned-ner',
#   'gtxygyzb/bert-finetuned-ner',
#   'sahilx13/sentenceBert-finetuned-yelp',
#   'nalinaksh/bert-finetuned-ner',
#   'rdpatilds/bert-finetuned-ner',
#   'vinayaksodar/bert-finetuned-ner',
#   'alexrider/bert-finetuned-squad',
#   'chriskim2273/IOTNation_Classification_Model_0.75_5K_AND_ORIGINAL_DATASET_BERT',
#   'tomaarsen/span-marker-bert-base-acronyms',
#   'chriskim2273/IOTNation_QA_Model_2.1_BERT_ORIGINAL_DATASET_ONLY',
#   'chriskim2273/IOTNation_Classification_Model_0.8_6K_AND_ORIGINAL_DATASET_BERT',
#   'drdspace/bert-finetuned-ner',
#   'magnustragardh/bert-finetuned-ner',
#   'ELggman/bert-finetuned-ner',
#   'fahadibrar/hugging_face_chap_4_3_uploading_model-model',
#   'peteryushunli/bert-finetuned-ner',
#   'chriskim2273/IOTNation_QA_Model_2.15_BERT_ORIGINAL_AND_UNK_DATASET',
#   'chriskim2273/IOTNation_QA_Model_3.0_BERT_ORIGINAL',
#   'chriskim2273/IOTNation_QA_Model_3.0_BERT_ORIGINAL_2e-5',
#   'chriskim2273/IOTNation_QA_Model_3.0_BERT_ORIGINAL_3e-5_512_LENGTH_3_EPOCH',
#   'bhushan4401/bert-fine-tuned-cola',
#   'nalinaksh/bert-finetuned-squad',
#   'Aansh123/test_trainer',
#   'minye819/bert-finetuned-ner',
#   'Vedmani/output',
#   'minye819/bert-finetuned-squad',
#   'Vedmani/imdb',
#   'chriskim2273/IOTNation_Classification_Model_1.0_6K_AND_ORIGINAL_DATASET_BERT_3_LABEL',
#   'Cchychen/bert-finetuned-ner',
#   'm0saan/bert-finetuned-ner',
#   'judy93536/bert-finetuned-ner',
#   'EzraWilliam/bert-finetuned-ner',
#   'om-ashish-soni/bert-finetuned-ner',
#   'om-ashish-soni/bert-finetuned-pos',
#   'chriskim2273/IOTNation_Classification_Model_1.1_7K_AND_ORIGINAL_DATASET_BERT_3_LABEL',
#   'vladjr/bert-finetuned-squad',
#   'pachequinho/sentiment_bert_imdb_10',
#   'akashmaggon/bert-finetuned-ner',
#   'BigAbdul/bert-finetuned-ner1',
#   'Dinendal/myModel',
#   'vuminhtue/bert-finetuned-ner',
#   'vuminhtue/bert-finetuned-squad',
#   'JJinBBangMan/bert-finetuned-ner',
#   'peteryushunli/bert-finetuned-squad',
#   'antoinerossupedu/bert-playground',
#   'LibrAI/bert-action-ro',
#   'alexandrechiari/bert-finetuned-ner',
#   'dima806/strong-password-checker-bert',
#   'LibrAI/bert-harmful-ro',
#   'btlgs2000/bert-finetuned-ner',
#   'yangdechuan/bert-base-cased-finetuned-mrpc',
#   'jennyc/bert-finetuned-squad',
#   'antoinerossupedu/token-classification-playground',
#   'magnustragardh/bert-finetuned-squad',
#   'peteryushunli/bert-finetuned-hausa_ner',
#   'badokorach/distil-bert-finetuned-agric',
#   'C57Box/bert-finetuned-ner',
#   'pachequinho/sentiment_bert_twitter_airlines_10',
#   'pachequinho/sentiment_bert_restaurant_10',
#   'nugget00/bert-finetuned-ner',
#   'oppokui/bert-fine-tuned-cola',
#   'UholoDala/sentence_sentiments_analysis_bert',
#   'nugget00/bert-finetuned-squad',
#   'tkoyama/bert-finetuned-ner',
#   'AnikaAI/bert-finetuned-ner',
#   'Ioana23/bert-finetuned-resumes-ner-2',
#   'profetize/bert-base-cased-wikitext2',
#   'tgoktug/my_bert_classification_model',
#   'benediktpri/finetuned_bert_injection',
#   'mdance/bert-finetuned-ner',
#   'Tsabing/bert-finetuned-ner',
#   'Ioana23/bert-finetuned-resumes-ner',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-1ep',
#   'Francesco-A/bert-finetuned-squad-v1',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-2ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-3ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-4ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-5ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-6ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-7ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-8ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-9ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-10ep',
#   'DannyAI/transformers-qa-movies',
#   'dreamboat26/bert-finetuned-ner',
#   'C57Box/bert-finetuned-squad',
#   'SaadoN/bert-finetuned-squad',
#   'btamm12/bert-base-cased-finetuned-wls-manual-1ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-2ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-3ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-4ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-5ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-6ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-7ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-8ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-9ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-10ep',
#   'LinYuting/bert-base-ner',
#   'anupamprataps/bert-base-cased-modified',
#   'NewtonKimathi/Covid_Vaccine_Sentiment_Analysis_Bert_based_Model',
#   'AnikaAI/bert-finetuned-squad',
#   'malonyu/bert-finetuned-squad',
#   'alex1qaz/bert-finetuned-goodsmemo-ner',
#   'Sonny4Sonnix/test_trainer',
#   'dmlea/bert-finetuned-ner',
#   'Giorgib/sato',
#   'Giorgib/bert-finetuned-on-squad',
#   'Terps/bert-finetuned-ner',
#   'holtbui/bert-finetuned-ner',
#   'GNReplay/bert-finetuned-ner',
#   'Giorgib/bert-finetuned-on-squad-tara',
#   'Gg1313/bert_finetuned_ner',
#   'ViktorDo/bert-finetuned-custom_Numerical_Traits',
#   'KingAsiedu/sentence_sentiments_analysis_bert',
#   'Jedida/sentence_sentiments_analysis_bert',
#   'Terps/bert-finetuned-squad',
#   'achris13/bert-finetuned-ner',
#   'jennyc/ip_rating',
#   'mundo-go/bert-finetuned-ner',
#   'thangvip/bert-finetuned-ner',
#   'dima806/fake-news-classifier',
#   'fundrais123/bert-finetuned-ner',
#   'adeep028/bert-fine-tuned-cola',
#   'burakabdi/bert-finetuned-ner',
#   'hemanth11/dummy',
#   'swang19/bert-fine-tuned-cola',
#   'Konic/bert-finetuned-ner',
#   'boimbukanbaim/bert-finetuned-ner',
#   'haihuynh/bert-fine-tuned-cola-tf',
#   'benroma/bert-finetuned-squad',
#   'pachequinho/sentiment_bert_imdb_prompts',
#   'pachequinho/sentiment_bert_imdb_prompts_nodup',
#   'penscola/sentence_sentiments_analysis_bert',
#   'hzsushiqiren/bert-finetuned-squad',
#   'cl-trier/kuglerk_adapted_bert-base-cased',
#   'RtwC/bert-finetuned-ner',
#   'qayqaq/bert-finetuned-ner',
#   '9au5a/test_trainer',
#   'Emma92/finetuned-bert-1k',
#   'prabhatsingh/bert-finetuned-squad',
#   'boimbukanbaim/bert-finetuned-squad',
#   'rayrico/bert-fine-tuned-cola',
#   'ThepineS/bert-finetuned-ner',
#   'Eduxim/output',
#   'rtilman/bert-base-cased-finetuned-swag',
#   'tiagofvb/bert-finetuned-yelp-review',
#   'plusbdw/bert-fine-tuned-cola',
#   'edzou/bert-finetuned-ner',
#   'tonystark0/bert-finetuned-ner',
#   'jonas-luehrs/bert-base-cased-textCLS-RHEOLOGY',
#   'jonas-luehrs/bert-base-cased-tokenCLS-CATALYST',
#   'jonas-luehrs/bert-base-cased-tokenCLS-BATTERY',
#   'adeep028/bert-finetuned-ner',
#   'jonas-luehrs/bert-base-cased-textCLS-PETROCHEMICAL',
#   'aarnow/bert-finetuned-squad',
#   'jonas-luehrs/bert-base-cased-MLM-chemistry',
#   'sam030/bert-fine-tuned-cola',
#   'mikrz/bert-finetuned-ner',
#   'Kiwihead15/bert-finetuned-ner',
#   'vazha72/bert-finetuned-ner-1',
#   'vaalto/test_trainer',
#   'sksayril/bert-finetuned-squad',
#   'Rabin233/bert-fine-tuned-cola',
#   'ShinDC/bert-finetuned-ner',
#   'vstudent/bert-finetuned-ner',
#   'vstudent/bert-finetuned-squad',
#   'mongdiutindei/bert-finetuned-ner',
#   'miahg/bert-finetuned-ner',
#   'ChrisX42/test_trainer',
#   'ChrisX42/trainer_projet7',
#   'pamelapaolacb/pruebaModeloTFM_Bert_es',
#   'pamelapaolacb/pruebaModeloTFM_Bert_in',
#   'ardanila/bert-base-cased-wikitext2',
#   'sooh098/bert-finetuned-ner',
#   'Safeer143/bert-finetuned-squad',
#   'ekachai/bert-finetuned-squad',
#   'Yuripoke10/bert-fine-tuned-cola',
#   'VityaVitalich/bert-base-cased-sst2',
#   'jkv53/bert-finetuned-ner',
#   'daethyra/bert-finetuned-ner',
#   'sooh098/bert-finetuned-squad',
#   'mangaphd/HausaBERTa',
#   'praneethvasarla/bert-finetuned-conll-ner',
#   'RtwC/berttest',
#   'sam-meshach-d/bert-finetuned-squad',
#   'RakhissBouchra/bert-finetuned-squad',
#   'Kapbl4/bert-finetuned-ner',
#   'MattiaParavisi/bert-base-cased-finetuned-dob',
#   'Leinadh/bert-finetuned-squad',
#   'Sakshi30/bert-finetuned-ner',
#   'guydebruyn/bert-finetuned-ner',
#   'jackboyla/span-marker-bert-base-fewnerd-coarse-super',
#   'Aioreus12/bert-fine-tuned-cola',
#   'khleeloo/bert-base-cased-wikitext2',
#   'mie-zhz/bert-finetuned-ner',
#   'Sakshi30/bert-finetuned-squad',
#   'xiajun2001/bert-finetuned-ner',
#   'alexpaunoiu/bert_finetune_onearticle_microbiology',
#   'theodoredc/bert-finetuned-squad',
#   'loganathanspr/bert-finetuned-ner',
#   'zeeshanparvez/bert-finetuned-squad',
#   'joseval2001/mi-super-modelo',
#   'SalmonAI123/bert-finetuned-squad',
#   'nicholas1890/test_trainer',
#   'aashish2211/bert-finetuned-squad',
#   'heenamir/bert-finetuned-ner',
#   'lauraparra28/bert-base-cased-finetuned-squad-bs_16',
#   'lauraparra28/bert-base-cased-finetuned-squad_v2-bs_16',
#   'PooRaj/span-marker-bert-base-fewnerd-coarse-super',
#   'louislian2341/bert-finetuned-ner',
#   'hung200504/result',
#   'liuyinjia/bert-finetuned-ner',
#   'Isuri97/holo_mlm_bert',
#   'lauraparra28/bert-base-cased-finetuned-squad_v2-bs_32',
#   'hung200504/1',
#   'tehranixyz/bert-finetuned-ner',
#   'hung200504/cpgqa',
#   'NguyenVanHieu1605/bert-base-ner-058',
#   'sdinger/bert-finetuned-ner',
#   'cleblainclb/bert-finetuned-ner',
#   'xiazhifang/bert-finetuned-ner',
#   'sdinger/bert-finetuned-squad',
#   'MuntasirHossain/bert-finetuned-ner',
#   'minea/bert-finetuned-ner',
#   'tw5n14/bert-finetuned-ner',
#   'fahbgoishdjfoiasf/bert-finetuned-ner',
#   'intpc/bert-base-cased-finetuned-ner',
#   'Denyol/FakeNews-bert-base-cased',
#   'Denyol/FakeNews-bert-base-cased-lowercase',
#   'greatakela/bert-finetuned-squad',
#   'Denyol/FakeNews-bert-base-cased-stopwords',
#   'Denyol/FakeNews-bert-base-cased-url',
#   'Denyol/FakeNews-bert-base-cased-html',
#   'Denyol/FakeNews-bert-base-cased-emoji',
#   'Denyol/FakeNews-bert-base-cased-punct',
#   'NicholasSynovic/forking-test',
#   'mangaphd/HausaSentiLex',
#   'joaomonteiro/bert-finetuned-ner',
#   'MattiaParavisi/bert-base-cased-word_sentence_1_1',
#   'hung200504/test-bert',
#   'lightsaber689/bert-finetuned-ner',
#   'Naveengo/bert-finetuned-on-ncbi__disease',
#   'queuemin/bert-finetuned-squad',
#   'mireiaplalis/bert-finetuned-ner',
#   'lltala/bert-base-cased-ner',
#   'bbatalo/bert-finetuned-ner',
#   'ClownChen/bert-finetuned-ner',
#   'fmurimi/bert-finetuned-ner',
#   'Gio200023/bert-finetuned-ner',
#   'schubertcarvalho/bert-finetuned-ner',
#   'aubreyrhodes/test_trainer',
#   'happy-ditto/bert-finetuned-ner',
#   'Nguyens/bert-finetuned-ner-accelerate',
#   'DEN-DDr/bert-finetuned-ner',
#   'MarthaK-Coder/test_trainer',
#   'Vedarutvija/bert-fine-tuned-cola',
#   'DanZter/StockZter_v1',
#   'meher-m2/assignment2_meher_test1',
#   'mpalaval/assignment2_attempt10',
#   'meher-m2/assignment2_meher_test2',
#   'chineidu/bert-finetuned-ner',
#   'mpalaval/assignment2_meher_test2',
#   'mpalaval/assignment2_attempt11',
#   'eeshclusive/bert-finetuned-ner',
#   'abdullah0x/bert-finetuned-squad',
#   'chunfengw/bert-finetuned-ner',
#   'rahulmukherji/bert-finetuned-ner',
#   'maddiehope/airlinetweets',
#   'mpalaval/assignment2_attempt12',
#   'mpalaval/assignment2_meher_test3',
#   'yitengm/bert-finetuned-ner',
#   'keylazy/bert-finetuned-ner',
#   'mpalaval/bert-finetuned-ner',
#   'mpalaval/bert-ner-2',
#   'XNSun519/bert-finetuned-ner',
#   'mpalaval/bert-ner-3',
#   'MrSoapman/scipaper-bert-finetuned-ner-larger',
#   'bleuLabs/bert-finetuned-squad',
#   'abdullah0x/bert-finetuned-ner',
#   'eeshclusive/bert-base-finetuned-ner',
#   'chineidu/bert-finetuned-sequence-classification',
#   'doejingle/sst2_fine_tuned',
#   'ncuxomun/bert-finetuned-ner',
#   'odunola/bert-based_cased-finetuned-financial-talk',
#   'CzarnyRycerz/bert-finetuned-ner',
#   'cehongw/ner-fine-tune-bert',
#   'Ryan20/sqoin_qa_model_first',
#   'shafnasir/bert-finetuned-ner',
#   'puchki2015/maitra1982-finetuned-bert-mrpc',
#   'Norika/bert-finetuned-ner',
#   'quangb1910128/bert-finetuned-squad',
#   'Gorgoura/bert-finetuned-ner',
#   'NourhanAbosaeed/bert-finetuned-ner',
#   'thinkscientist/test_trainer',
#   'LukeZekes/bert-finetuned-squad',
#   'nntdoan/bert-finetuned-ner',
#   'Lifan-Z/bert-finetuned-ner',
#   'ztang4/bert-base-cased-wikitext2',
#   'Luukdejong123/bert-finetuned-ner',
#   'Pasta5634/bert-finetuned-ner',
#   'Qiuxuan/bert-finetuned-ner',
#   'laura0000/bert-finetuned-ner',
#   'Mabel465/bert-finetuned-ner',
#   'rubinho/bert-finetuned-ner',
#   'csNoHug/bert-finetuned-ner',
#   'ShoumikN/bert-finetuned-cola',
#   'guydebruyn/bert-finetuned-squad',
#   'mongdiutindei/bert-finetuned-squad',
#   'IvoSchols/bert-finetuned-ner',
#   'nimamehrafar/TM-A2-bert-finetuned',
#   'loukawijne/bert-finetuned-ner',
#   'minh282906/bert-finetuned-squad',
#   'Mabel465/bert-finetuned-ner.default_parameters',
#   'nimamehrafar/bert-finetuned-ner',
#   'RoxieC/bert-finetuned-ner',
#   'nova-sqoin/hotel_qa_model',
#   'vb-oracle/test_trainer',
#   'jamaya/bert-finetuned-ner',
#   'goldwellshampoo/bert-finetuned-ner',
#   'SophieH17/bert-finetuned-ner',
#   'ayushsengar/bert-finetuned-ner',
#   'shubingxl/bert-finetuned-ner',
#   'MajkelDcember/bert-finetuned-ner',
#   'ArdourXL/bert-finetuned-ner',
#   'youngmountain28/bert-finetuned-ner',
#   'Tabon/bert-finetuned-ner',
#   'phantatbach/bert-finetuned-ner-accelerate',
#   'epitta/bert-finetuned-ner',
#   'remva/bert-finetuned-ner',
#   'epitta/bert-finetuned-ner-noval',
#   'capybaraaa/bert-finetuned-ner',
#   'Bugabooo30/bert-finetuned-ner',
#   'Zhushuai/bert-finetuned-ner',
#   'WJK233/bert-finetuned-ner',
#   'promptora11/bert-finetuned-squad',
#   'Apucs/bert-fine-tuned-cola',
#   'bambadij/sentiment_analysis_model_trainer',
#   'nimamehrafar/TM-02-Base-Bert-Finetuned-NER',
#   'J1mb0o/bert-finetuned-ner-noval',
#   'Theoreticallyhugo/bert-ner-essays-find_span',
#   'J1mb0o/bert-finetuned-batch32-lr1e-5',
#   'J1mb0o/bert-finetuned-batch32-lr3e-5',
#   'J1mb0o/bert-finetuned-batch32-lr5e-5',
#   'Matthijs99/bert-finetuned-ner',
#   'J1mb0o/bert-finetuned-batch16-lr1e-5',
#   'J1mb0o/bert-finetuned-batch16-lr3e-5',
#   'J1mb0o/bert-finetuned-batch16-lr5e-5',
#   'FabianJennrich/bert-finetuned-ner',
#   'Bramve/bert-finetuned-ner',
#   'csariyildiz/bert-finetuned-ner',
#   'ygmrdgan/bert-finetuned-ner',
#   'barbarosisik/bert-finetuned-ner',
#   'rubinho/bert-finetuned-ner-optuna',
#   'KemseiF/bert-finetuned-ner',
#   'remva/bert-baselines',
#   'ygmrdgan/bert-finetuned-ner_lr1e-05_bs16',
#   'mikrz/bert-linnaeus-ner',
#   'ygmrdgan/bert-finetuned-ner_lr1e-05_bs32',
#   'ygmrdgan/bert-finetuned-ner_lr0.001_bs16',
#   'HermBrens/bert-finetuned-ner-2',
#   'ygmrdgan/bert-finetuned-ner_lr0.001_bs32',
#   'PelagiaKalpakidou/bert-finetuned-ner',
#   'ygmrdgan/bert-finetuned-ner_lr2e-05_bs16',
#   'remva/results_lr1e-05_wd0.0',
#   'remva/results_lr1e-05_wd0.01',
#   'remva/results_lr1e-05_wd0.1',
#   'remva/results_lr0.0001_wd0.0',
#   'remva/results_lr0.0001_wd0.01',
#   'remva/results_lr0.0001_wd0.1',
#   'ygmrdgan/bert-finetuned-ner_lr2e-05_bs32',
#   'remva/results_lr0.001_wd0.0',
#   'remva/results_lr0.001_wd0.01',
#   'remva/results_lr0.001_wd0.1',
#   'remva/best',
#   'Matthijs99/bert-finetuned-ner_1',
#   'Matthijs99/bert-finetuned-ner_2',
#   'Matthijs99/bert-finetuned-ner_3',
#   'Matthijs99/bert-finetuned-ner_4',
#   'Matthijs99/bert-finetuned-ner_5',
#   'Matthijs99/bert-finetuned-ner_6',
#   'Matthijs99/bert-finetuned-ner_7',
#   'Matthijs99/bert-finetuned-ner_8',
#   'noshamedevil/bert-finetuned-ner',
#   'FabianJennrich/bert-finetuned-ner-2',
#   'remva/base',
#   'remva/base2',
#   'linearch/bert-finetuned-ner',
#   'HeitorMatt/bert-finetuned-ner',
#   'phantatbach/bert-finetuned-squad-accelerate',
#   'Zynab/finetuned-bert-mrpc',
#   'tejabale/bert-finetuned-squad',
#   'tejabale/bert-finetuned-squad2',
#   'tejabale/bert-finetuned-squad3',
#   'stephen423/bert-base-cased-wikitext2',
#   'borough-oblast/bert-finetuned-ner',
#   'aaronayitey/Sentiment-classfication-distilBERT-model',
#   '1kkiren/bert-base-cased-mms-ru-tuned',
#   'AlisaKn/bert-finetuned-ner',
#   'Theoreticallyhugo/bert-ner-essays-label_span',
#   'dracero/bert-finetuned-ner',
#   'liziyang625/bert-fine-tuned-cola',
#   'Tavres/bert-finetuned-squad',
#   'rzeydelis/discord-crypto-scam-detector',
#   'liziyang625/bert-fine-tuned-cola-tf',
#   'mpalaval/bert-goemotions-15epochs-run2',
#   'youngjung/bert-finetuned-squad',
#   'christti/bert-finetuned-squad',
#   'scotssman/bert-finetuned-ner',
#   'p1gm1/bert-finetuned-squad',
#   'rzeydelis/test_trainer',
#   'rzeydelis/test_trainers',
#   'preetk21/bert-finetuned-ner',
#   'FrankQin/test_trainer',
#   'banw/bert-finetuned-ner',
#   'p1gm1/bert-finetuned-squad-accelerate',
#   'Treether/bert-finetuned-ner',
#   'thangvip/bert-finetuned-ner-cti',
#   'tomaarsen/span-marker-bert-base-orgs',
#   'michamcs/bert-law-text-classification',
#   'StrawHatDragon/bert-finetuned-ner',
#   'greyfoss/bert-finetuned-ner',
#   'spokkazo/bert-finetuned-test-pepe2',
#   'irenema/model_en',
#   'password1/bert-base-cased-finetuned-wikitext2',
#   'Areeb123/NER_BERT_Finetune_Model',
#   'WEIDD1122/weijie1122',
#   's91023/test_trainer',
#   'toqi/bert-finetuned-squad',
#   'suleiman-younes/bert-finetuned-ner',
#   'hydrochii/text_classify_model',
#   'ericli2/bert-finetuned-squad',
#   'annabellehuether/bert-base-cased-finetuned-news-test',
#   'buscaholding/buscacerveja-beer',
#   'annabellehuether/bert-base-cased-finetuned-news-small',
#   'annabellehuether/bert-base-cased-finetuned-news-small_2',
#   'annabellehuether/bert-base-cased-finetuned-news-all',
#   'soravoid/bert-twitch-emotes',
#   'michaelsungboklee/bert-finetuned-ner',
#   'spokkazo/bert-finetuned-squad',
#   'StrawHatDrag0n/bert-finetuned-ner',
#   'annabellehuether/bert-base-cased-finetuned-news-all-t5',
#   'nnhwin/bert-finetuned-squad',
#   'zylfws/est_trainer',
#   'annabellehuether/bert-base-cased-finetuned-news-all-pegasus',
#   'Shayawn/bert-finetuned-ner',
#   'tintinjian12999/bert-finetuned-ner',
#   'annabellehuether/bert-base-cased-finetuned-news-all-pegasus-batch16',
#   'annabellehuether/bert-base-cased-finetuned-news-all-t5-16batch',
#   'annabellehuether/bert-base-cased-finetuned-news-all-test_set',
#   'annabellehuether/bert-base-cased-finetuned-news-all-batch16',
#   'marynwangwu/bert-base-cased-finetuned-news-all',
#   'capnatpat/bert-finetuned-squad',
#   'David-ing/BertFinetunedNer0',
#   'linh2001hanoi/bert-finetuned-ner',
#   'aisuko/ft_bert_base_cased',
#   'AhmedEladl/bert-base-cased-finetuned-swag',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-1',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-2',
#   'sriramahesh2000/finetuned-bert-mrpc',
#   'Prezily/test_trainer',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-3',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-32batch',
#   'galaxy78/my_awesome_wnut_model',
#   'thongnef/bert-finetuned-ner-cti',
#   'honeyybadger/bert-finetuned-ner',
#   'iyoussef1079/bert-finetuned-ner',
#   'galaxy78/ChatGPT_Project',
#   'sunny2309/bert-finetuned-for-ner',
#   'May33/bert-finetuned-ner',
#   'annabellehuether/bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'mireiaplalis/bert-finetuned-ner-cadec',
#   'mireiaplalis/bert-base-cased-finetuned-ner-cadec',
#   'annabellehuether/t5-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'annabellehuether/bert-base-cased-news-16batch_10epoch_2e5lr_01wd',
#   'annabellehuether/bert-base-cased-news-16batch_5epoch_2e5lr_1wd',
#   'annabellehuether/bert-base-cased-news-16batch_5epoch_2e5lr_01wd',
#   'annabellehuether/100tok-t5-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'charlie1111/bert-finetuned-squad',
#   'hfjbkim/bert-finetuned-ner',
#   'JHhan/bert-finetuned-ner',
#   'annabellehuether/100tok-pegasus-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'skonmeme/bert-finetuned-ner',
#   'csNoHug/bert-base-cased-finetuned-ner-cadec',
#   'Nurmukhamed/bert-finetuned-ner',
#   'meribabayaan/bert-base-cased-finetuned-wikitext2',
#   'Di99di/bert-base-cased-finetuned-wikitext2',
#   'annabellehuether/pegasus-200tok-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'AbhishekkV19/test_trainer',
#   'delayedkarma/bert-finetuned-ner',
#   'milenamoreira/bert-finetuned-squad',
#   'sumeyyecelik/my_qa_model',
#   'sandorscog/judicial_brazil',
#   'linqus/bert-finetuned-ner',
#   'mogam/bert-base-cased-wikitext2',
#   'dadashzadeh/bert-base-news-or-informational-nft-english',
#   'vmg1957/bert-finetuned-squad',
#   'rudyTzhan/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-5k-vul-hyp-exp',
#   'AbhishekkV19/bert-base-cased-5k-vul-hyp-exp-10ep',
#   'delayedkarma/bert-finetuned-squad',
#   'jungwoo9/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-exp-10ep',
#   'ShynBui/s27',
#   'Prezily/bert-yelp',
#   'jinya425/bert-base-cased_for_sentiment_analysis',
#   'Shriganesh/bert-finetuned-ner',
#   'Dangurangu/bert-finetuned-ner',
#   'alexpaunoiu/bert_finetune_classification',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-10w-exp-10ep',
#   'tornqvistmax/bert-finetuned-ner',
#   'Hyun24/bert-finetuned-ner',
#   'Katster/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-10w-exp-10ep-s42-1',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-10w-exp-10ep-s42-2',
#   'quantman/bert-finetuned-ner',
#   'eeeelzvt/bert-base-cased-finetuned-wikitext2',
#   'AravindVCyber/bert-fine-tuned-cola',
#   'mireiaplalis/bert-base-cased-finetuned-ner-cadec-no-iob',
#   'raoel/bert-finetuned-ner',
#   'sul-lix/bert-fine-tuned-cola',
#   'tornqvistmax/bert_finetuned_ner_a',
#   'Castling/bert-finetuned-ner',
#   'tornqvistmax/bert_finetuned_ner_b',
#   'naninya/bert-finetuned-ner',
#   'kondakovilia/bert-base-cased-finetuned-wikitext2',
#   'mialby/bert-base-cased-finetuned-wikitext2',
#   'ArchiRad/bert-base-cased-finetuned-wikitext2',
#   'Yzuygulama/bert-finetuned-squad',
#   'AJlEXANDR/bert-base-cased-finetuned-wikitext2',
#   'Numerical-wizard/bert-base-cased-finetuned-wikitext2',
#   'ichmrklv/bert-base-cased-finetuned-wikitext2',
#   'meoskis/bert-base-cased-finetuned-wikitext2',
#   'MrGummyl3ear/bert-base-cased-finetuned-wikitext2',
#   'MANTISS13/bert-base-cased-finetuned-wikitext2',
#   'Prokopeva/bert-base-cased-finetuned-wikitext2',
#   'No-Sock/bert-base-cased-finetuned-wikitext2',
#   'ksushausenko/bert-base-cased-finetuned-wikitext2',
#   'Azaliya-Vagizova/bert-base-cased-finetuned-wikitext2',
#   'userdiawatch/bert-base-cased-finetuned-wikitext2',
#   'luckykittty/bert-base-cased-finetuned-wikitext2',
#   'winehertz/bert-base-cased-finetuned-wikitext2',
#   'Alena-Poluboyarinova/bert-base-cased-finetuned-wikitext2',
#   'Maxlin12/bert-base-cased-finetuned-wikitext2',
#   'Shriganesh/bert-finetuned-squad',
#   'polina164/bert-base-cased-finetuned-wikitext2',
#   'GlebPS/bert-base-cased-finetuned-wikitext2',
#   'olga-mi-2002/bert-base-cased-finetuned-wikitext2',
#   'qwebeklu4ik/bert-base-cased-finetuned-wikitext2',
#   'MaksKhramtsov/bert-base-cased-finetuned-wikitext2',
#   'esakov-s/bert-base-cased-finetuned-wikitext2',
#   'Memori707/bert-base-cased-finetuned-wikitext2',
#   'Kyyoto/bert-base-cased-finetuned-wikitext2',
#   'raoel/bert-finetuned-squad',
#   'rinkorn/bert-finetuned-ner',
#   'vmg1957/test_trainer',
#   'abhir00p/bert-finetuned-squad-rup',
#   'abhir00p/bert-finetuned-squad-rup-1',
#   'Rezakakooee/bert-finetuned-ner',
#   'xxxxxcz/dihuxia',
#   'neural-net-rahul/bert-finetuned-ner',
#   'Artanis1551/bert_trainer',
#   'koakande/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42',
#   'AbhishekkV19/bert-base-cased-ft5-6ep-s42',
#   'beskrovnayaaaa/bert-base-cased-finetuned-wikitext2',
#   'rafaelperezctes/mi-super-modelo',
#   'EleanorLin/bert-finetuned-squad',
#   'Artanis1551/bert_sentiment_trainer',
#   'hemarun/bert-finetuned-ner',
#   'zeon8985army/bert-base-bible2',
#   'wenjun123/token_calssification_model',
#   'neural-net-rahul/distilbert-finetuned-imdb',
#   'zeon8985army/bert-base-bible3',
#   'zeon8985army/bert-base-bible3-numbers',
#   'zeon8985army/bert-base-bible4',
#   'Karachik/bert-base-cased-finetuned-wikitext2',
#   'chvas37/bert-base-cased-finetuned-wikitext2',
#   'JoseAntonioBarrancoBernabe/mi-super-modelo',
#   'wgpak/bert-finetuned-ner',
#   'Dagonez/bert-finetuned-squad',
#   'jnmrr/bert-finetuned-squad',
#   'MinhMinh09/span-marker-bert-base-fewnerd-coarse-super',
#   'TaupoB/bert-base-cased-finetuned-wikitext2',
#   'andrewma5/bert-finetuned-ner-tutorial',
#   'AnnaKupri/bert-base-cased-finetuned-wikitext2',
#   'jay-dit/bert-base-cased-finetuned-wikitext2',
#   'neural-net-rahul/bert-finetuned-squad',
#   'smallfish166/bert-finetuned-ner',
#   'Alchem/bert-finetuned-squad',
#   'Bramve/bert-finetuned-ner-CRF',
#   'Bramve/bert-finetuned-ner-bilstm',
#   'qualis2006/bert-finetuned-ner',
#   'GandegaH/bert-base-cased-wikitext2',
#   'GandegaH/bert-base-cased-finetuned-wikitext2',
#   'nademaaltijd/bert-finetuned-ner',
#   'cmunhozc/news-ranking-ft-bert',
#   'eunseol/bert-finetuned-ner',
#   'Lipas007/bert-finetuned-ner',
#   'NastyaKorneeva/bert-base-cased-finetuned-wikitext2',
#   'BanUrsus/bert-finetuned-ner_NLP-course-chapter7-section1',
#   'Stefan228/bert-base-cased-finetuned-wikitext2',
#   'peni0k/bert-base-cased-finetuned-wikitext2',
#   'Vishu7797/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-2',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-exp3',
#   'adsazad/sikhchat-transformer',
#   'rafaelzimmermann/bert-finetuned-ner',
#   'rafaelzimmermann/bert-finetuned-squad',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-toplessonly',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-no-topless',
#   'jth1911/bert-finetuned-ner',
#   'vladoksss/bert-base-cased-finetuned-wikitext2',
#   'pnr-svc/bert-en-ner',
#   'plusbdw/bert-finetuned-ner',
#   'lourvalli/bert-finetuned-ner',
#   'ilbaks/bert-finetuned-ner',
#   'Sphealls/bert-base-cased-finetuned-wikitext2',
#   'AntonZhar/bert-base-cased-finetuned-wikitext2',
#   'amasiukevich/dummy_bert_model',
#   '4kew/bert-finetuned-squad',
#   'ricerlu/bert-finetuned-ner',
#   'SharonTudi/DIALOGUE_second_model',
#   'KDarrrya/bert-base-cased-finetuned-wikitext2',
#   'raoel/bert-finetuned-ASAP-AEStask',
#   'rinkorn/bert-finetuned-squad',
#   'yunakuz/bert-base-cased-finetuned-wikitext2',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42-v2',
#   'rjomega/bert-finetuned-squad',
#   'Utshav/bert-fined-tuned-cola',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42-exp1',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42-exp2',
#   'TunahanGokcimen/tun-en-ner',
#   'TunahanGokcimen/Question-Answering-Bert-base-cased-new',
#   'mikrz/bert-vir_naeus-ner',
#   'AbhishekkV19/bert-base-cased-ft5-topless-sent-removed-3ep-s42',
#   'AbhishekkV19/bert-base-cased-ft5-topless-wrd-removed-3ep-s42',
#   'AbhishekkV19/bert-base-cased-ft5-topless-wrd-0-label-added-3ep-s42',
#   'JeaHyung/test_trainer',
#   'merthacioglu/bert-base-cased-finetuned-squad-b16',
#   'stanpony/medical-diagnosis-classification-model',
#   'stanpony/medical-diagnosis-classifier',
#   'raj-p/bert-finetuned-ner',
#   'FocacciaX/bert-finetuned-ner',
#   'BenRongey/GoEmo',
#   'nguyenthanhasia/RuletakerBert',
#   'rohitdiwane/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-mnli-model1',
#   'varun-v-rao/bert-base-cased-mnli-model2',
#   'varun-v-rao/bert-base-cased-mnli-model3',
#   'varun-v-rao/bert-base-cased-mnli-model4',
#   'monkeyerKong/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-mnli-model5',
#   'varun-v-rao/bert-base-cased-mnli-model6',
#   'varun-v-rao/bert-base-cased-mnli-model7',
#   'varun-v-rao/bert-base-cased-mnli-model8',
#   'varun-v-rao/bert-base-cased-mnli-model9',
#   'varun-v-rao/bert-base-cased-mnli-model10',
#   'Brrrrt/bert-finetuned-squad',
#   'ovieyra21/mi-super-modelo',
#   'varun-v-rao/bert-base-cased-snli-model1',
#   'varun-v-rao/bert-base-cased-snli-model2',
#   'varun-v-rao/bert-base-cased-snli-model3',
#   'raj-p/bert-finetuned-ner-medical',
#   'varun-v-rao/bert-base-cased-snli-model4',
#   'varun-v-rao/bert-base-cased-snli-model5',
#   'varun-v-rao/bert-base-cased-snli-model6',
#   'varun-v-rao/bert-base-cased-snli-model7',
#   'varun-v-rao/bert-base-cased-snli-model8',
#   'varun-v-rao/bert-base-cased-snli-model9',
#   'varun-v-rao/bert-base-cased-snli-model10',
#   'jarekr/bert-finetuned-squad',
#   'clecam/bert-fine-tune-cola',
#   'mahmed31/bert-finetuned-ner',
#   'ConorParis32/dummy',
#   'sevvalozdamar/bert-base-cased-finetuned',
#   'zanetworker/bert-finetuned-ner',
#   'Kaelan/bert-finetuned-squad',
#   'jarektovar/mi-super-modelo',
#   'Malek1410/bert_project_test_trainer',
#   'ConorParis32/TFdummy',
#   'moctarsmal/bert-ner-chunks',
#   '4n7h0ny/fin3Tun3Glu3',
#   'hwang2006/bert-finetuned-squad',
#   'Quanult/bert-finetuned-ner',
#   'jsathish1990/test_trainer',
#   'rcade/test_falcon_model_learning',
#   'TunahanGokcimen/bert-base-cased-ner',
#   'katzenbach/test_trainer',
#   'Soon2340/bert-finetuned-ner',
#   'rcade/finetuned-bert-mrpc',
#   'rcade/glue_rcade_test_model',
#   'rcade/testing_model',
#   'katzenbach/PrimerClasificadorSencillo',
#   'sheduele/bert_C_2',
#   'yukihirop/bert-finetuned-squad',
#   'bmd1905/bert-finetuned-squad',
#   'ccova/mi-super-modelo',
#   'llkenll/BertModel',
#   'brightlee6/test_trainer',
#   'shahzebnaveed/bert-finetuned-squad',
#   'syedmhamudulhasan/bert-base-cased-wikitext2',
#   'katzenbach/testMetaphor',
#   'katzenbach/testMetaphor2',
#   'BanUrsus/bert-base-cased-finetuned-squad_nlp-course-chapter7-section6',
#   'AhmedKaisar/bert-ner',
#   'mrvsrc/bert-finetuned-ner',
#   'YeoJiSu/bert-fine-tuned-cola',
#   'katzenbach/testMetaphor3',
#   'Capstone-lpx/my_awesome_eli5_mlm_model',
#   'bSariturk/bert-fine-tuned-cola',
#   'Palistha/bert-finetuned-ner',
#   'eagle0504/finetuned-bert-mrpc',
#   'DanielAvelar09/mi-super-model',
#   'azureabaaba/bert-finetuned-squad',
#   'Palistha/bert-finetuned-squad',
#   'YeoJiSu/bert-finetuned-ner',
#   'Kamaljp/bert-base-cased-wiki',
#   'sbulut/bert-finetuned-ner',
#   'manibt1993/ncbi_disease_ner',
#   'Siddharthparmar7/bookcorpus_MLM',
#   'suyu0712/bert-finetuned-squad',
#   'timothee1996/bert-finetuned-ner',
#   'sbulut/bert-finetuned-squad',
#   'Skier8402/bert-finetuned-ner',
#   'HeZhang1019/bert-finetuned-squad',
#   'DjSteker/mi-super-modelo',
#   'manibt1993/huner_ncbi_disease',
#   'rahhal/bert-finetuned-squad',
#   'Raymond0012/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-lora-592K-snli-model1',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-snli-model1',
#   'varun-v-rao/bert-base-cased-lora-592K-snli-model2',
#   'varun-v-rao/bert-base-cased-lora-592K-snli-model3',
#   'StatsGary/bert-cola-finetuned',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-snli-model2',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-snli-model3',
#   'blaze999/finetuned-ner-conll',
#   'manibt1993/huner_disease',
#   'micoff/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-squad-model1',
#   'Ankush-Chander/bert-finetuned-ner',
#   'gavinqiangli/bert-base-cased-wikitext2',
#   'varun-v-rao/bert-base-cased-lora-591K-squad-model1',
#   'varun-v-rao/bert-base-cased-squad-model2',
#   'varun-v-rao/bert-base-cased-lora-591K-squad-model2',
#   'varun-v-rao/bert-base-cased-lora-591K-squad-model3',
#   'varun-v-rao/bert-base-cased-squad-model3',
#   'felixng2k/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-squad-model1',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-squad-model2',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-squad-model3',
#   'Shruthi-S/shruthicapstone-bertbase-qa',
#   'rtdoit/bert-fine-tuned-cola',
#   'yacineai7/bert-finetuned-ner',
#   'Priyanshuchaudhary2425/AI-Text-Ditactor',
#   'Rajdonthi/bert-finetuned-ner',
#   'serhii-korobchenko/bert-finetuned-ner',
#   'SamBuchl/bert-finetuned-ner',
#   'Khaledai/test-trainer',
#   'sophiayk20/bert-finetuned-squad',
#   'Nattipon/bert-finetuned-squad',
#   'destinyg423/bert-finetuned-ner',
#   'lbukowiec/bert-finetuned-ner',
#   'Hlindroth/test_trainer',
#   'McChicken/bert-finetuned-squad',
#   'Shruthi-S/capstone-bert-qa',
#   'Fm505/bert-finetuned-ner',
#   'gskhs/bert-finetuned-squad',
#   'rahulshah9713/bert-base-cased-wikitext2',
#   'lorisrossi/test-bert-finetuned-cola',
#   'sjunique/bert-finetuned-ner',
#   'tormartin/bert-finetuned-squad',
#   'alexyuanj/bert-finetuned-squad',
#   'Peak1260/bert-finetuned-squad',
#   'Hernan1970/mi-super-modelo',
#   'PW1116/bert-finetuned-squad',
#   'ttamer/bert-finetuned-squad',
#   'jasontnguyen/bert-finetuned-squad',
#   'Cesar2109/mi-super-modelo',
#   'felixbrock/test_trainer',
#   'ruru2701/filmbert_v1',
#   'ruru2701/Models',
#   'ruru2701/filmbertv1',
#   'ThuyNT03/SOMD-train-bert-v1',
#   'sjunique/bert-finetuned-squad',
#   'Pegaso183/clasificador_estrellas',
#   'JacobEisner/bert-finetuned-squad',
#   'liminding/bert-finetuned-squad',
#   'neimp/bert-finetuned-squad',
#   'duykha0511/bert-base-cased_',
#   'Dakotazoid56/bert-finetuned-squad',
#   'kannt-im/bert-finetuned-ner',
#   'noelg02/mi-super-modelo',
#   'surribasg/mi-super-modelo',
#   'nbelle/bert-finetuned-squad',
#   'anshuman-ucsb/bert-finetuned-squad',
#   'junghyun-tiger/bert-finetuned-squad',
#   'ThuyNT03/SOMD-train-bert-v2',
#   'julianfrank1151/bert-finetuned-squad',
#   'minshengchan/bert-finetuned-ner',
#   'Bzhao344/bert-finetuned-squad',
#   'cxbn12/bert-finetuned-ner',
#   'ThuyNT03/SOMD-train-bert-v3',
#   'ethan3048/bert-finetuned-squad',
#   'chosenone80/bert-ner-test-1',
#   'pabsdsr/bert-finetuned-squad',
#   'thecriticalpoint/test_trainer',
#   'free126/bert-finetuned-squad',
#   'siru712/bert-finetuned-squad',
#   'farfalla/bert-finetuned-ner',
#   'kpazawala/bert-finetuned-squad',
#   'mr-rov/bert-base-casedhealth_model1',
#   'mr-rov/test_trainer',
#   'chosenone80/bert-ner-test-2',
#   'yang598/bert-finetuned-squad',
#   'christianbaker/bert-finetuned-squad',
#   'jasonjongwoo/bert-finetuned-squad',
#   'tschlunk/bert-finetuned-squad',
#   'ashleybudman/bert-finetuned-squad',
#   'SNHE/bert-fine-tuned-cola',
#   'engmufic/finetuned-model',
#   'sadhaklal/bert-base-cased-finetuned-conll2003-ner',
#   'newyorksteak/bert-finetuned-squad',
#   'wrschiff/bert-finetuned-squad',
#   'Elizabeth2002/bert-finetuned-squad',
#   'hj279559/bert-finetuned-squad',
#   'NastasiaM/bert-finetuned-squad',
#   'seculoro1/bert-finetuned-squad',
#   'ondinehunter/bert-finetuned-squad',
#   'KhosrojerdiA/bert-finetuned-ner',
#   'tianyuzhangterry/bert-finetuned-ner',
#   'phusroyal/bert-base-cased-massive_intent',
#   'VikrantRamesh/bert-base-cased-wikitext2',
#   'Norms02/bert-finetuned-squad',
#   'DrGwin/bert-base-cased-finetuned-swag',
#   'yousseftarhri/bert-base-cased_fine_tuned',
#   'AICHEN008/bert-finetuned-ner',
#   'teknow/test_trainer',
#   'rfdv/bert-fine-tuned-cola',
#   'Corbanp/bert-finetuned-ner',
#   'ab-ai/pii_model',
#   'Davidzhang123/bert-fine-tuned-cola',
#   'jamesLeeeeeee/code-search-net-tokenizer',
#   'Mayank1999/bert-finetuned-ner',
#   'Skier8402/bert-finetuned-squad',
#   'nitinai/bert-finetuned-ner',
#   'jerrish/bert-finetuned-ner',
#   'Concises/bert-finetuned-ner',
#   'Sebas012/mi-super-modelo',
#   'mithegooie/bert-finetuned-ner',
#   'Fah-d/bert-finetuned-ner',
#   'CHENG028/bert-finetuned-squad',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K1',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K2',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K3',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K4',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K5',
#   'dtorber/bert-base-cased_K1',
#   'dtorber/bert-base-cased_K2',
#   'dtorber/bert-base-cased_K3',
#   'dtorber/bert-base-cased_K4',
#   'dtorber/bert-base-cased_K5',
#   'willherbert27/bert-finetuned-combo-textbook',
#   'Ernani/bert-finetuned-ner',
#   'WhisperHeart/my_awesome_model',
#   'Sourabh1407/bert-finetuned-squad',
#   'akshit-g/distilbert-base-cased',
#   'shubhamgantayat/reward_model_anthropic',
#   'dtorber/bert-base-cased',
#   'mhassan101/bert-finetuned-squad-ds',
#   'dhanushbitra/bert_sentiment_trainer',
#   'gingun18/bert-finetuned-ner',
#   'rizvi-rahil786/bert-base-canadaWildfire',
#   'alex-atelo/bert-finetuned-ner',
#   'asifabcder/bert-finetuned-ner',
#   'rizvi-rahil786/bert-base-cased-equadorEarthquake',
#   'rizvi-rahil786/bert-base-cased-cyclonePam',
#   'rizvi-rahil786/bert-base-cased-greeceWildfire',
#   'rizvi-rahil786/bert-base-cased-laShoot',
#   'rizvi-rahil786/bert-base-cased-matthewCategory',
#   'rizvi-rahil786/bert-base-cased-mexicoQuake',
#   'rizvi-rahil786/bert-base-cased-usflood',
#   'lukeBB/bert-finetuned-squad',
#   'rizvi-rahil786/bert-base-cased-shShooting',
#   'rizvi-rahil786/bert-base-cased-pakQuake',
#   'rizvi-rahil786/bert-base-cased-hblast',
#   'rizvi-rahil786/bert-base-cased-uflood',
#   'rizvi-rahil786/bert-base-cased-kaikouraEarthquake',
#   'emptyasso/uploadhub',
#   'vicky6/bert-finetuned-ner',
#   'who-does/bert-base-cased-wikitext2',
#   'rizvi-rahil786/bert-base-cased-hardaDerail',
#   'rizvi-rahil786/bert-base-cased-hagupitCategory',
#   'siddharth2050/sid-ner',
#   'GorBatchLab/bert-finetuned-squad',
#   'mithegooie/bert-finetuned-squad',
#   'lloydmeta/bert-fine-tuned-cola',
#   'michaelcheung/bert-finetuned-ner',
#   'serhii-korobchenko/bert-finetuned-squad',
#   'PrasannaL/test_trainer',
#   ...],
#  'quantized': ['Xenova/bert-base-cased', 'wdavies/extract-answer-from-text'],
#  'dataset': ['legacy-datasets/wikipedia', 'bookcorpus/bookcorpus']}

# %%
file_path = f"./models/{model_name}/Contents.json"  # 원하는 폴더 경로 지정

with open(file_path, "r", encoding="utf-8") as f:
    model_contents_data = json.load(f)

# %%
merged_dict = {**row_dict, **model_side_data, **model_contents_data}
print(merged_dict)
# Out:
# {'id': 'google-bert/bert-base-cased', 'author': 'google-bert', 'created_at': '2022-03-02 23:29:04+00:00', 'last_modified': '2024-02-19 11:02:26+00:00', 'private': False, 'gated': 'False', 'disabled': None, 'downloads': 4819762, 'likes': 231, 'library_name': 'transformers, pytorch, tf, jax, safetensors, bert', 'tags': "['exbert', 'autotrain_compatible', 'endpoints_compatible']", 'pipeline_tag': 'fill-mask', 'arxiv': 'arxiv:1810.04805', 'dataset': ['legacy-datasets/wikipedia', 'bookcorpus/bookcorpus'], 'region': 'region:us', 'license': 'license:apache-2.0', 'language': 'en', 'adapter': ['identrics/wasper_propaganda_detection_en', 'tomhodemon/query_encoder_lora_v1', 'tomhodemon/passage_encoder_lora_v1', 'tomhodemon/fever-query_encoder-lora-bsz16-77588-gradacc1', 'tomhodemon/fever_passage_encoder-lora-bsz16-77588-gradacc1', 'MaximTitarenkoUIT/reward_test_on_filtered_data_lora', 'MonkeyDdonut/aiVshuman_bert_2epochs', 'sumittyagi25/test_trainer', 'Rastael/bert-base-cased-sequence-classification', 'stanpony/ml_medical_diagnosis', 'EliasKD/LoRA-imdb-seq-cls', 'EliasKD/LoRA-my-dataset-seq-cls', 'MaggieZhang/test_trainer', 'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_irony', 'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_emotion', 'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_hate', 'rajevan123/STS-Lora-Fine-Tuning-Capstone-bert-testing-70-with-lower-r-mid', 'Jahanzeb1/BERT-TextClassification', 'dfoc99/bert-base-cased-finetuned-Astronomy_Thesaurus', 'stonedsmv/BERT-peft_LoRA', 'abhishekkumaribt/bert-lora', 'ElMad/luxuriant-squid-867', 'ElMad/capable-doe-250', 'ElMad/persistent-dog-343', 'ElMad/unequaled-ape-267', 'ElMad/bouncy-colt-342', 'Prasanna05/ner_lora_output', 'ElMad/grandiose-horse-172', 'ElMad/beautiful-worm-91', 'ElMad/marvelous-pug-454', 'ElMad/receptive-hog-274', 'ElMad/rogue-crane-540', 'ElMad/gaudy-hound-390', 'joshuaspear/bert-base-cased-finetuned-health-qa', 'Deban/output', 'katsuchi/results', 'katsuchi/bert-dair-ai-emotion', 'katsuchi/bert-dair-ai-emotion-testing'], 'finetune': ['Kushtrim/bert-base-cased-biomedical-ner', 'Zabihin/Symptom_to_Diagnosis', 'HUMADEX/polish_medical_ner', 'VolkanSimsir/ber-finetuned-ner', 'viswadarshan06/pd-bert', 'luheng/bert-finetuned-ner', 'tartuNLP/EstBERT', 'kamalkraj/bert-base-cased-ner-conll2003', 'dimboump/glue_sst_classifier', 'juancopi81/bert-finetuned-ner', 'juancopi81/course-bert-finetuned-squad', 'phamvanlinh143/bert-finetuned-ner', 'dsantistevan/bert-base-cased-bert-yoga-finetuned', 'nickprock/bert-finetuned-ner-ontonotes', 'jfcruz13/bert-finetuned-ner', 'noahgift/hf_fine_tune_hello_world', 'Asmit/bert-finetuned-squad', 'jtlicardo/bert-finetuned-bpmn', 'asifraza/results', 'jtlicardo/bpmn-information-extraction', 'zhengke/bert-finetuned-squad', 'jtlicardo/bpmn-information-extraction-v2', 'qfrodicio/bert-finetuned-gesture-prediction-21-classes', 'tomaarsen/span-marker-bert-base-fewnerd-fine-super', 'sooolee/bert-finetuned-squad-v1', 'Iiro/bert_reviews', 'TechnicalMoruJiii/bert-finetuned-squad', 'johnjose223/Bert_Squad', 'Shariar433/bert-finetuned-ner', 'sitthichokpaugchan/finetuned-bert', 'MUmairAB/bert-ner', 'insub/bert-finetuned-squad', 'imtiaz114/bert-finetuned-ner-baseline-1', 'slickdata/finetuned-Sentiment-classfication-BERT-model', 'elvis-d/elvis_bert_base', 'conorjudge/bert-finetuned-ner', 'chunwoolee0/bert-finetuned-ner', 'mulinski/bert-finetuned-squad', 'PhysHunter/bert-finetuned-squad', 'sarahflan/bert-finetuned-ner', 'Kerz/bbc', 'UholoDala/tweet_sentiments_analysis_bert', 'penscola/tweet_sentiments_analysis_bert', 'KingAsiedu/tweet_sentiments_analysis_bert', 'stefaniftime/bert-finetuned-ner-v2', 'Jedida/tweet_sentiments_analysis_bert', 'Yaopu/bert-finetuned-squad', 'ronyw7/BERT_PatentAbstract2IncomeGroup_2500', 'EricPeter/bert-finetuned-squad', 'badokorach/bert-finetuned-squad', 'youngsun05/bert-finetuned-squad', 'happyone/bert-finetuned-ner', 'VCool22/bert-finetuned-ner', 'Gikubu/Gikubu_bert_base', 'aman38649/bert-finetuned-ner', 'donske ...

# %%
merged_dict
# Out:
# {'id': 'google-bert/bert-base-cased',
#  'author': 'google-bert',
#  'created_at': '2022-03-02 23:29:04+00:00',
#  'last_modified': '2024-02-19 11:02:26+00:00',
#  'private': False,
#  'gated': 'False',
#  'disabled': None,
#  'downloads': 4819762,
#  'likes': 231,
#  'library_name': 'transformers, pytorch, tf, jax, safetensors, bert',
#  'tags': "['exbert', 'autotrain_compatible', 'endpoints_compatible']",
#  'pipeline_tag': 'fill-mask',
#  'arxiv': 'arxiv:1810.04805',
#  'dataset': ['legacy-datasets/wikipedia', 'bookcorpus/bookcorpus'],
#  'region': 'region:us',
#  'license': 'license:apache-2.0',
#  'language': 'en',
#  'adapter': ['identrics/wasper_propaganda_detection_en',
#   'tomhodemon/query_encoder_lora_v1',
#   'tomhodemon/passage_encoder_lora_v1',
#   'tomhodemon/fever-query_encoder-lora-bsz16-77588-gradacc1',
#   'tomhodemon/fever_passage_encoder-lora-bsz16-77588-gradacc1',
#   'MaximTitarenkoUIT/reward_test_on_filtered_data_lora',
#   'MonkeyDdonut/aiVshuman_bert_2epochs',
#   'sumittyagi25/test_trainer',
#   'Rastael/bert-base-cased-sequence-classification',
#   'stanpony/ml_medical_diagnosis',
#   'EliasKD/LoRA-imdb-seq-cls',
#   'EliasKD/LoRA-my-dataset-seq-cls',
#   'MaggieZhang/test_trainer',
#   'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_irony',
#   'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_emotion',
#   'TransferGraph/bert-base-cased-finetuned-lora-tweet_eval_hate',
#   'rajevan123/STS-Lora-Fine-Tuning-Capstone-bert-testing-70-with-lower-r-mid',
#   'Jahanzeb1/BERT-TextClassification',
#   'dfoc99/bert-base-cased-finetuned-Astronomy_Thesaurus',
#   'stonedsmv/BERT-peft_LoRA',
#   'abhishekkumaribt/bert-lora',
#   'ElMad/luxuriant-squid-867',
#   'ElMad/capable-doe-250',
#   'ElMad/persistent-dog-343',
#   'ElMad/unequaled-ape-267',
#   'ElMad/bouncy-colt-342',
#   'Prasanna05/ner_lora_output',
#   'ElMad/grandiose-horse-172',
#   'ElMad/beautiful-worm-91',
#   'ElMad/marvelous-pug-454',
#   'ElMad/receptive-hog-274',
#   'ElMad/rogue-crane-540',
#   'ElMad/gaudy-hound-390',
#   'joshuaspear/bert-base-cased-finetuned-health-qa',
#   'Deban/output',
#   'katsuchi/results',
#   'katsuchi/bert-dair-ai-emotion',
#   'katsuchi/bert-dair-ai-emotion-testing'],
#  'finetune': ['Kushtrim/bert-base-cased-biomedical-ner',
#   'Zabihin/Symptom_to_Diagnosis',
#   'HUMADEX/polish_medical_ner',
#   'VolkanSimsir/ber-finetuned-ner',
#   'viswadarshan06/pd-bert',
#   'luheng/bert-finetuned-ner',
#   'tartuNLP/EstBERT',
#   'kamalkraj/bert-base-cased-ner-conll2003',
#   'dimboump/glue_sst_classifier',
#   'juancopi81/bert-finetuned-ner',
#   'juancopi81/course-bert-finetuned-squad',
#   'phamvanlinh143/bert-finetuned-ner',
#   'dsantistevan/bert-base-cased-bert-yoga-finetuned',
#   'nickprock/bert-finetuned-ner-ontonotes',
#   'jfcruz13/bert-finetuned-ner',
#   'noahgift/hf_fine_tune_hello_world',
#   'Asmit/bert-finetuned-squad',
#   'jtlicardo/bert-finetuned-bpmn',
#   'asifraza/results',
#   'jtlicardo/bpmn-information-extraction',
#   'zhengke/bert-finetuned-squad',
#   'jtlicardo/bpmn-information-extraction-v2',
#   'qfrodicio/bert-finetuned-gesture-prediction-21-classes',
#   'tomaarsen/span-marker-bert-base-fewnerd-fine-super',
#   'sooolee/bert-finetuned-squad-v1',
#   'Iiro/bert_reviews',
#   'TechnicalMoruJiii/bert-finetuned-squad',
#   'johnjose223/Bert_Squad',
#   'Shariar433/bert-finetuned-ner',
#   'sitthichokpaugchan/finetuned-bert',
#   'MUmairAB/bert-ner',
#   'insub/bert-finetuned-squad',
#   'imtiaz114/bert-finetuned-ner-baseline-1',
#   'slickdata/finetuned-Sentiment-classfication-BERT-model',
#   'elvis-d/elvis_bert_base',
#   'conorjudge/bert-finetuned-ner',
#   'chunwoolee0/bert-finetuned-ner',
#   'mulinski/bert-finetuned-squad',
#   'PhysHunter/bert-finetuned-squad',
#   'sarahflan/bert-finetuned-ner',
#   'Kerz/bbc',
#   'UholoDala/tweet_sentiments_analysis_bert',
#   'penscola/tweet_sentiments_analysis_bert',
#   'KingAsiedu/tweet_sentiments_analysis_bert',
#   'stefaniftime/bert-finetuned-ner-v2',
#   'Jedida/tweet_sentiments_analysis_bert',
#   'Yaopu/bert-finetuned-squad',
#   'ronyw7/BERT_PatentAbstract2IncomeGroup_2500',
#   'EricPeter/bert-finetuned-squad',
#   'badokorach/bert-finetuned-squad',
#   'youngsun05/bert-finetuned-squad',
#   'happyone/bert-finetuned-ner',
#   'VCool22/bert-finetuned-ner',
#   'Gikubu/Gikubu_bert_base',
#   'aman38649/bert-finetuned-ner',
#   'donskerclass/bert-finetuned-ner',
#   'tr-aravindan/bert-finetuned-ner',
#   'nickovchinnikov/bert-finetuned-ner',
#   'stefaniftime/bert-finetuned-squad',
#   'runningsnake/bert-finetuned-ner',
#   'badokorach/bert-base-cased-finetuned',
#   'shre-db/bert-finetuned-ner',
#   'jakobkruse/bert-finetuned-squad',
#   'cssupport/bert-finetuned-ner',
#   'autosyrup/bert',
#   'mundepankaj/bert-finetuned-ner',
#   'Joelt0/bert-finetuned-ner',
#   'fadliaulawi/bert-finetuned-squad',
#   'deepanshu30699/bert-finetuned-ner',
#   'Sambosis/bert-base-cased-finetuned-swag',
#   'YanJiangJerry/baseline_bert-base-cased_epoch3_batch4_lr2e-05_w0.01',
#   'danexl/bert-finetuned-ner',
#   'ShynBui/s1',
#   'ShynBui/s2',
#   'ShynBui/s3',
#   'sgugger/push-to-hub-test-2',
#   'ShynBui/s4',
#   'ShynBui/s5',
#   'ShynBui/s7',
#   'ShynBui/s8',
#   'ShynBui/s9',
#   'ShynBui/s10',
#   'ShynBui/s11',
#   'ShynBui/s13',
#   'ShynBui/s14',
#   'ShynBui/s15',
#   'ShynBui/s16',
#   'ShynBui/s17',
#   'ShynBui/s19',
#   'ShynBui/s20',
#   'ShynBui/s21',
#   'ShynBui/s23',
#   'ShynBui/s25',
#   'ShynBui/s28',
#   'chunwoolee0/bert-finetuned-squad',
#   'y-taki/my-model',
#   'y-taki/my-model-0808',
#   'adon81/bert-finetuned-ner',
#   'Shafaet02/bert-fine-tuned-cola',
#   'Francesco-A/bert-finetuned-ner',
#   'sachin2000keshav/bert-finetuned-ner',
#   'gtxygyzb/bert-finetuned-ner',
#   'sahilx13/sentenceBert-finetuned-yelp',
#   'nalinaksh/bert-finetuned-ner',
#   'rdpatilds/bert-finetuned-ner',
#   'vinayaksodar/bert-finetuned-ner',
#   'alexrider/bert-finetuned-squad',
#   'chriskim2273/IOTNation_Classification_Model_0.75_5K_AND_ORIGINAL_DATASET_BERT',
#   'tomaarsen/span-marker-bert-base-acronyms',
#   'chriskim2273/IOTNation_QA_Model_2.1_BERT_ORIGINAL_DATASET_ONLY',
#   'chriskim2273/IOTNation_Classification_Model_0.8_6K_AND_ORIGINAL_DATASET_BERT',
#   'drdspace/bert-finetuned-ner',
#   'magnustragardh/bert-finetuned-ner',
#   'ELggman/bert-finetuned-ner',
#   'fahadibrar/hugging_face_chap_4_3_uploading_model-model',
#   'peteryushunli/bert-finetuned-ner',
#   'chriskim2273/IOTNation_QA_Model_2.15_BERT_ORIGINAL_AND_UNK_DATASET',
#   'chriskim2273/IOTNation_QA_Model_3.0_BERT_ORIGINAL',
#   'chriskim2273/IOTNation_QA_Model_3.0_BERT_ORIGINAL_2e-5',
#   'chriskim2273/IOTNation_QA_Model_3.0_BERT_ORIGINAL_3e-5_512_LENGTH_3_EPOCH',
#   'bhushan4401/bert-fine-tuned-cola',
#   'nalinaksh/bert-finetuned-squad',
#   'Aansh123/test_trainer',
#   'minye819/bert-finetuned-ner',
#   'Vedmani/output',
#   'minye819/bert-finetuned-squad',
#   'Vedmani/imdb',
#   'chriskim2273/IOTNation_Classification_Model_1.0_6K_AND_ORIGINAL_DATASET_BERT_3_LABEL',
#   'Cchychen/bert-finetuned-ner',
#   'm0saan/bert-finetuned-ner',
#   'judy93536/bert-finetuned-ner',
#   'EzraWilliam/bert-finetuned-ner',
#   'om-ashish-soni/bert-finetuned-ner',
#   'om-ashish-soni/bert-finetuned-pos',
#   'chriskim2273/IOTNation_Classification_Model_1.1_7K_AND_ORIGINAL_DATASET_BERT_3_LABEL',
#   'vladjr/bert-finetuned-squad',
#   'pachequinho/sentiment_bert_imdb_10',
#   'akashmaggon/bert-finetuned-ner',
#   'BigAbdul/bert-finetuned-ner1',
#   'Dinendal/myModel',
#   'vuminhtue/bert-finetuned-ner',
#   'vuminhtue/bert-finetuned-squad',
#   'JJinBBangMan/bert-finetuned-ner',
#   'peteryushunli/bert-finetuned-squad',
#   'antoinerossupedu/bert-playground',
#   'LibrAI/bert-action-ro',
#   'alexandrechiari/bert-finetuned-ner',
#   'dima806/strong-password-checker-bert',
#   'LibrAI/bert-harmful-ro',
#   'btlgs2000/bert-finetuned-ner',
#   'yangdechuan/bert-base-cased-finetuned-mrpc',
#   'jennyc/bert-finetuned-squad',
#   'antoinerossupedu/token-classification-playground',
#   'magnustragardh/bert-finetuned-squad',
#   'peteryushunli/bert-finetuned-hausa_ner',
#   'badokorach/distil-bert-finetuned-agric',
#   'C57Box/bert-finetuned-ner',
#   'pachequinho/sentiment_bert_twitter_airlines_10',
#   'pachequinho/sentiment_bert_restaurant_10',
#   'nugget00/bert-finetuned-ner',
#   'oppokui/bert-fine-tuned-cola',
#   'UholoDala/sentence_sentiments_analysis_bert',
#   'nugget00/bert-finetuned-squad',
#   'tkoyama/bert-finetuned-ner',
#   'AnikaAI/bert-finetuned-ner',
#   'Ioana23/bert-finetuned-resumes-ner-2',
#   'profetize/bert-base-cased-wikitext2',
#   'tgoktug/my_bert_classification_model',
#   'benediktpri/finetuned_bert_injection',
#   'mdance/bert-finetuned-ner',
#   'Tsabing/bert-finetuned-ner',
#   'Ioana23/bert-finetuned-resumes-ner',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-1ep',
#   'Francesco-A/bert-finetuned-squad-v1',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-2ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-3ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-4ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-5ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-6ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-7ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-8ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-9ep',
#   'btamm12/bert-base-cased-finetuned-wls-whisper-10ep',
#   'DannyAI/transformers-qa-movies',
#   'dreamboat26/bert-finetuned-ner',
#   'C57Box/bert-finetuned-squad',
#   'SaadoN/bert-finetuned-squad',
#   'btamm12/bert-base-cased-finetuned-wls-manual-1ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-2ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-3ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-4ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-5ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-6ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-7ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-8ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-9ep',
#   'btamm12/bert-base-cased-finetuned-wls-manual-10ep',
#   'LinYuting/bert-base-ner',
#   'anupamprataps/bert-base-cased-modified',
#   'NewtonKimathi/Covid_Vaccine_Sentiment_Analysis_Bert_based_Model',
#   'AnikaAI/bert-finetuned-squad',
#   'malonyu/bert-finetuned-squad',
#   'alex1qaz/bert-finetuned-goodsmemo-ner',
#   'Sonny4Sonnix/test_trainer',
#   'dmlea/bert-finetuned-ner',
#   'Giorgib/sato',
#   'Giorgib/bert-finetuned-on-squad',
#   'Terps/bert-finetuned-ner',
#   'holtbui/bert-finetuned-ner',
#   'GNReplay/bert-finetuned-ner',
#   'Giorgib/bert-finetuned-on-squad-tara',
#   'Gg1313/bert_finetuned_ner',
#   'ViktorDo/bert-finetuned-custom_Numerical_Traits',
#   'KingAsiedu/sentence_sentiments_analysis_bert',
#   'Jedida/sentence_sentiments_analysis_bert',
#   'Terps/bert-finetuned-squad',
#   'achris13/bert-finetuned-ner',
#   'jennyc/ip_rating',
#   'mundo-go/bert-finetuned-ner',
#   'thangvip/bert-finetuned-ner',
#   'dima806/fake-news-classifier',
#   'fundrais123/bert-finetuned-ner',
#   'adeep028/bert-fine-tuned-cola',
#   'burakabdi/bert-finetuned-ner',
#   'hemanth11/dummy',
#   'swang19/bert-fine-tuned-cola',
#   'Konic/bert-finetuned-ner',
#   'boimbukanbaim/bert-finetuned-ner',
#   'haihuynh/bert-fine-tuned-cola-tf',
#   'benroma/bert-finetuned-squad',
#   'pachequinho/sentiment_bert_imdb_prompts',
#   'pachequinho/sentiment_bert_imdb_prompts_nodup',
#   'penscola/sentence_sentiments_analysis_bert',
#   'hzsushiqiren/bert-finetuned-squad',
#   'cl-trier/kuglerk_adapted_bert-base-cased',
#   'RtwC/bert-finetuned-ner',
#   'qayqaq/bert-finetuned-ner',
#   '9au5a/test_trainer',
#   'Emma92/finetuned-bert-1k',
#   'prabhatsingh/bert-finetuned-squad',
#   'boimbukanbaim/bert-finetuned-squad',
#   'rayrico/bert-fine-tuned-cola',
#   'ThepineS/bert-finetuned-ner',
#   'Eduxim/output',
#   'rtilman/bert-base-cased-finetuned-swag',
#   'tiagofvb/bert-finetuned-yelp-review',
#   'plusbdw/bert-fine-tuned-cola',
#   'edzou/bert-finetuned-ner',
#   'tonystark0/bert-finetuned-ner',
#   'jonas-luehrs/bert-base-cased-textCLS-RHEOLOGY',
#   'jonas-luehrs/bert-base-cased-tokenCLS-CATALYST',
#   'jonas-luehrs/bert-base-cased-tokenCLS-BATTERY',
#   'adeep028/bert-finetuned-ner',
#   'jonas-luehrs/bert-base-cased-textCLS-PETROCHEMICAL',
#   'aarnow/bert-finetuned-squad',
#   'jonas-luehrs/bert-base-cased-MLM-chemistry',
#   'sam030/bert-fine-tuned-cola',
#   'mikrz/bert-finetuned-ner',
#   'Kiwihead15/bert-finetuned-ner',
#   'vazha72/bert-finetuned-ner-1',
#   'vaalto/test_trainer',
#   'sksayril/bert-finetuned-squad',
#   'Rabin233/bert-fine-tuned-cola',
#   'ShinDC/bert-finetuned-ner',
#   'vstudent/bert-finetuned-ner',
#   'vstudent/bert-finetuned-squad',
#   'mongdiutindei/bert-finetuned-ner',
#   'miahg/bert-finetuned-ner',
#   'ChrisX42/test_trainer',
#   'ChrisX42/trainer_projet7',
#   'pamelapaolacb/pruebaModeloTFM_Bert_es',
#   'pamelapaolacb/pruebaModeloTFM_Bert_in',
#   'ardanila/bert-base-cased-wikitext2',
#   'sooh098/bert-finetuned-ner',
#   'Safeer143/bert-finetuned-squad',
#   'ekachai/bert-finetuned-squad',
#   'Yuripoke10/bert-fine-tuned-cola',
#   'VityaVitalich/bert-base-cased-sst2',
#   'jkv53/bert-finetuned-ner',
#   'daethyra/bert-finetuned-ner',
#   'sooh098/bert-finetuned-squad',
#   'mangaphd/HausaBERTa',
#   'praneethvasarla/bert-finetuned-conll-ner',
#   'RtwC/berttest',
#   'sam-meshach-d/bert-finetuned-squad',
#   'RakhissBouchra/bert-finetuned-squad',
#   'Kapbl4/bert-finetuned-ner',
#   'MattiaParavisi/bert-base-cased-finetuned-dob',
#   'Leinadh/bert-finetuned-squad',
#   'Sakshi30/bert-finetuned-ner',
#   'guydebruyn/bert-finetuned-ner',
#   'jackboyla/span-marker-bert-base-fewnerd-coarse-super',
#   'Aioreus12/bert-fine-tuned-cola',
#   'khleeloo/bert-base-cased-wikitext2',
#   'mie-zhz/bert-finetuned-ner',
#   'Sakshi30/bert-finetuned-squad',
#   'xiajun2001/bert-finetuned-ner',
#   'alexpaunoiu/bert_finetune_onearticle_microbiology',
#   'theodoredc/bert-finetuned-squad',
#   'loganathanspr/bert-finetuned-ner',
#   'zeeshanparvez/bert-finetuned-squad',
#   'joseval2001/mi-super-modelo',
#   'SalmonAI123/bert-finetuned-squad',
#   'nicholas1890/test_trainer',
#   'aashish2211/bert-finetuned-squad',
#   'heenamir/bert-finetuned-ner',
#   'lauraparra28/bert-base-cased-finetuned-squad-bs_16',
#   'lauraparra28/bert-base-cased-finetuned-squad_v2-bs_16',
#   'PooRaj/span-marker-bert-base-fewnerd-coarse-super',
#   'louislian2341/bert-finetuned-ner',
#   'hung200504/result',
#   'liuyinjia/bert-finetuned-ner',
#   'Isuri97/holo_mlm_bert',
#   'lauraparra28/bert-base-cased-finetuned-squad_v2-bs_32',
#   'hung200504/1',
#   'tehranixyz/bert-finetuned-ner',
#   'hung200504/cpgqa',
#   'NguyenVanHieu1605/bert-base-ner-058',
#   'sdinger/bert-finetuned-ner',
#   'cleblainclb/bert-finetuned-ner',
#   'xiazhifang/bert-finetuned-ner',
#   'sdinger/bert-finetuned-squad',
#   'MuntasirHossain/bert-finetuned-ner',
#   'minea/bert-finetuned-ner',
#   'tw5n14/bert-finetuned-ner',
#   'fahbgoishdjfoiasf/bert-finetuned-ner',
#   'intpc/bert-base-cased-finetuned-ner',
#   'Denyol/FakeNews-bert-base-cased',
#   'Denyol/FakeNews-bert-base-cased-lowercase',
#   'greatakela/bert-finetuned-squad',
#   'Denyol/FakeNews-bert-base-cased-stopwords',
#   'Denyol/FakeNews-bert-base-cased-url',
#   'Denyol/FakeNews-bert-base-cased-html',
#   'Denyol/FakeNews-bert-base-cased-emoji',
#   'Denyol/FakeNews-bert-base-cased-punct',
#   'NicholasSynovic/forking-test',
#   'mangaphd/HausaSentiLex',
#   'joaomonteiro/bert-finetuned-ner',
#   'MattiaParavisi/bert-base-cased-word_sentence_1_1',
#   'hung200504/test-bert',
#   'lightsaber689/bert-finetuned-ner',
#   'Naveengo/bert-finetuned-on-ncbi__disease',
#   'queuemin/bert-finetuned-squad',
#   'mireiaplalis/bert-finetuned-ner',
#   'lltala/bert-base-cased-ner',
#   'bbatalo/bert-finetuned-ner',
#   'ClownChen/bert-finetuned-ner',
#   'fmurimi/bert-finetuned-ner',
#   'Gio200023/bert-finetuned-ner',
#   'schubertcarvalho/bert-finetuned-ner',
#   'aubreyrhodes/test_trainer',
#   'happy-ditto/bert-finetuned-ner',
#   'Nguyens/bert-finetuned-ner-accelerate',
#   'DEN-DDr/bert-finetuned-ner',
#   'MarthaK-Coder/test_trainer',
#   'Vedarutvija/bert-fine-tuned-cola',
#   'DanZter/StockZter_v1',
#   'meher-m2/assignment2_meher_test1',
#   'mpalaval/assignment2_attempt10',
#   'meher-m2/assignment2_meher_test2',
#   'chineidu/bert-finetuned-ner',
#   'mpalaval/assignment2_meher_test2',
#   'mpalaval/assignment2_attempt11',
#   'eeshclusive/bert-finetuned-ner',
#   'abdullah0x/bert-finetuned-squad',
#   'chunfengw/bert-finetuned-ner',
#   'rahulmukherji/bert-finetuned-ner',
#   'maddiehope/airlinetweets',
#   'mpalaval/assignment2_attempt12',
#   'mpalaval/assignment2_meher_test3',
#   'yitengm/bert-finetuned-ner',
#   'keylazy/bert-finetuned-ner',
#   'mpalaval/bert-finetuned-ner',
#   'mpalaval/bert-ner-2',
#   'XNSun519/bert-finetuned-ner',
#   'mpalaval/bert-ner-3',
#   'MrSoapman/scipaper-bert-finetuned-ner-larger',
#   'bleuLabs/bert-finetuned-squad',
#   'abdullah0x/bert-finetuned-ner',
#   'eeshclusive/bert-base-finetuned-ner',
#   'chineidu/bert-finetuned-sequence-classification',
#   'doejingle/sst2_fine_tuned',
#   'ncuxomun/bert-finetuned-ner',
#   'odunola/bert-based_cased-finetuned-financial-talk',
#   'CzarnyRycerz/bert-finetuned-ner',
#   'cehongw/ner-fine-tune-bert',
#   'Ryan20/sqoin_qa_model_first',
#   'shafnasir/bert-finetuned-ner',
#   'puchki2015/maitra1982-finetuned-bert-mrpc',
#   'Norika/bert-finetuned-ner',
#   'quangb1910128/bert-finetuned-squad',
#   'Gorgoura/bert-finetuned-ner',
#   'NourhanAbosaeed/bert-finetuned-ner',
#   'thinkscientist/test_trainer',
#   'LukeZekes/bert-finetuned-squad',
#   'nntdoan/bert-finetuned-ner',
#   'Lifan-Z/bert-finetuned-ner',
#   'ztang4/bert-base-cased-wikitext2',
#   'Luukdejong123/bert-finetuned-ner',
#   'Pasta5634/bert-finetuned-ner',
#   'Qiuxuan/bert-finetuned-ner',
#   'laura0000/bert-finetuned-ner',
#   'Mabel465/bert-finetuned-ner',
#   'rubinho/bert-finetuned-ner',
#   'csNoHug/bert-finetuned-ner',
#   'ShoumikN/bert-finetuned-cola',
#   'guydebruyn/bert-finetuned-squad',
#   'mongdiutindei/bert-finetuned-squad',
#   'IvoSchols/bert-finetuned-ner',
#   'nimamehrafar/TM-A2-bert-finetuned',
#   'loukawijne/bert-finetuned-ner',
#   'minh282906/bert-finetuned-squad',
#   'Mabel465/bert-finetuned-ner.default_parameters',
#   'nimamehrafar/bert-finetuned-ner',
#   'RoxieC/bert-finetuned-ner',
#   'nova-sqoin/hotel_qa_model',
#   'vb-oracle/test_trainer',
#   'jamaya/bert-finetuned-ner',
#   'goldwellshampoo/bert-finetuned-ner',
#   'SophieH17/bert-finetuned-ner',
#   'ayushsengar/bert-finetuned-ner',
#   'shubingxl/bert-finetuned-ner',
#   'MajkelDcember/bert-finetuned-ner',
#   'ArdourXL/bert-finetuned-ner',
#   'youngmountain28/bert-finetuned-ner',
#   'Tabon/bert-finetuned-ner',
#   'phantatbach/bert-finetuned-ner-accelerate',
#   'epitta/bert-finetuned-ner',
#   'remva/bert-finetuned-ner',
#   'epitta/bert-finetuned-ner-noval',
#   'capybaraaa/bert-finetuned-ner',
#   'Bugabooo30/bert-finetuned-ner',
#   'Zhushuai/bert-finetuned-ner',
#   'WJK233/bert-finetuned-ner',
#   'promptora11/bert-finetuned-squad',
#   'Apucs/bert-fine-tuned-cola',
#   'bambadij/sentiment_analysis_model_trainer',
#   'nimamehrafar/TM-02-Base-Bert-Finetuned-NER',
#   'J1mb0o/bert-finetuned-ner-noval',
#   'Theoreticallyhugo/bert-ner-essays-find_span',
#   'J1mb0o/bert-finetuned-batch32-lr1e-5',
#   'J1mb0o/bert-finetuned-batch32-lr3e-5',
#   'J1mb0o/bert-finetuned-batch32-lr5e-5',
#   'Matthijs99/bert-finetuned-ner',
#   'J1mb0o/bert-finetuned-batch16-lr1e-5',
#   'J1mb0o/bert-finetuned-batch16-lr3e-5',
#   'J1mb0o/bert-finetuned-batch16-lr5e-5',
#   'FabianJennrich/bert-finetuned-ner',
#   'Bramve/bert-finetuned-ner',
#   'csariyildiz/bert-finetuned-ner',
#   'ygmrdgan/bert-finetuned-ner',
#   'barbarosisik/bert-finetuned-ner',
#   'rubinho/bert-finetuned-ner-optuna',
#   'KemseiF/bert-finetuned-ner',
#   'remva/bert-baselines',
#   'ygmrdgan/bert-finetuned-ner_lr1e-05_bs16',
#   'mikrz/bert-linnaeus-ner',
#   'ygmrdgan/bert-finetuned-ner_lr1e-05_bs32',
#   'ygmrdgan/bert-finetuned-ner_lr0.001_bs16',
#   'HermBrens/bert-finetuned-ner-2',
#   'ygmrdgan/bert-finetuned-ner_lr0.001_bs32',
#   'PelagiaKalpakidou/bert-finetuned-ner',
#   'ygmrdgan/bert-finetuned-ner_lr2e-05_bs16',
#   'remva/results_lr1e-05_wd0.0',
#   'remva/results_lr1e-05_wd0.01',
#   'remva/results_lr1e-05_wd0.1',
#   'remva/results_lr0.0001_wd0.0',
#   'remva/results_lr0.0001_wd0.01',
#   'remva/results_lr0.0001_wd0.1',
#   'ygmrdgan/bert-finetuned-ner_lr2e-05_bs32',
#   'remva/results_lr0.001_wd0.0',
#   'remva/results_lr0.001_wd0.01',
#   'remva/results_lr0.001_wd0.1',
#   'remva/best',
#   'Matthijs99/bert-finetuned-ner_1',
#   'Matthijs99/bert-finetuned-ner_2',
#   'Matthijs99/bert-finetuned-ner_3',
#   'Matthijs99/bert-finetuned-ner_4',
#   'Matthijs99/bert-finetuned-ner_5',
#   'Matthijs99/bert-finetuned-ner_6',
#   'Matthijs99/bert-finetuned-ner_7',
#   'Matthijs99/bert-finetuned-ner_8',
#   'noshamedevil/bert-finetuned-ner',
#   'FabianJennrich/bert-finetuned-ner-2',
#   'remva/base',
#   'remva/base2',
#   'linearch/bert-finetuned-ner',
#   'HeitorMatt/bert-finetuned-ner',
#   'phantatbach/bert-finetuned-squad-accelerate',
#   'Zynab/finetuned-bert-mrpc',
#   'tejabale/bert-finetuned-squad',
#   'tejabale/bert-finetuned-squad2',
#   'tejabale/bert-finetuned-squad3',
#   'stephen423/bert-base-cased-wikitext2',
#   'borough-oblast/bert-finetuned-ner',
#   'aaronayitey/Sentiment-classfication-distilBERT-model',
#   '1kkiren/bert-base-cased-mms-ru-tuned',
#   'AlisaKn/bert-finetuned-ner',
#   'Theoreticallyhugo/bert-ner-essays-label_span',
#   'dracero/bert-finetuned-ner',
#   'liziyang625/bert-fine-tuned-cola',
#   'Tavres/bert-finetuned-squad',
#   'rzeydelis/discord-crypto-scam-detector',
#   'liziyang625/bert-fine-tuned-cola-tf',
#   'mpalaval/bert-goemotions-15epochs-run2',
#   'youngjung/bert-finetuned-squad',
#   'christti/bert-finetuned-squad',
#   'scotssman/bert-finetuned-ner',
#   'p1gm1/bert-finetuned-squad',
#   'rzeydelis/test_trainer',
#   'rzeydelis/test_trainers',
#   'preetk21/bert-finetuned-ner',
#   'FrankQin/test_trainer',
#   'banw/bert-finetuned-ner',
#   'p1gm1/bert-finetuned-squad-accelerate',
#   'Treether/bert-finetuned-ner',
#   'thangvip/bert-finetuned-ner-cti',
#   'tomaarsen/span-marker-bert-base-orgs',
#   'michamcs/bert-law-text-classification',
#   'StrawHatDragon/bert-finetuned-ner',
#   'greyfoss/bert-finetuned-ner',
#   'spokkazo/bert-finetuned-test-pepe2',
#   'irenema/model_en',
#   'password1/bert-base-cased-finetuned-wikitext2',
#   'Areeb123/NER_BERT_Finetune_Model',
#   'WEIDD1122/weijie1122',
#   's91023/test_trainer',
#   'toqi/bert-finetuned-squad',
#   'suleiman-younes/bert-finetuned-ner',
#   'hydrochii/text_classify_model',
#   'ericli2/bert-finetuned-squad',
#   'annabellehuether/bert-base-cased-finetuned-news-test',
#   'buscaholding/buscacerveja-beer',
#   'annabellehuether/bert-base-cased-finetuned-news-small',
#   'annabellehuether/bert-base-cased-finetuned-news-small_2',
#   'annabellehuether/bert-base-cased-finetuned-news-all',
#   'soravoid/bert-twitch-emotes',
#   'michaelsungboklee/bert-finetuned-ner',
#   'spokkazo/bert-finetuned-squad',
#   'StrawHatDrag0n/bert-finetuned-ner',
#   'annabellehuether/bert-base-cased-finetuned-news-all-t5',
#   'nnhwin/bert-finetuned-squad',
#   'zylfws/est_trainer',
#   'annabellehuether/bert-base-cased-finetuned-news-all-pegasus',
#   'Shayawn/bert-finetuned-ner',
#   'tintinjian12999/bert-finetuned-ner',
#   'annabellehuether/bert-base-cased-finetuned-news-all-pegasus-batch16',
#   'annabellehuether/bert-base-cased-finetuned-news-all-t5-16batch',
#   'annabellehuether/bert-base-cased-finetuned-news-all-test_set',
#   'annabellehuether/bert-base-cased-finetuned-news-all-batch16',
#   'marynwangwu/bert-base-cased-finetuned-news-all',
#   'capnatpat/bert-finetuned-squad',
#   'David-ing/BertFinetunedNer0',
#   'linh2001hanoi/bert-finetuned-ner',
#   'aisuko/ft_bert_base_cased',
#   'AhmedEladl/bert-base-cased-finetuned-swag',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-1',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-2',
#   'sriramahesh2000/finetuned-bert-mrpc',
#   'Prezily/test_trainer',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-3',
#   'annabellehuether/bert-base-cased-supreme-court-summaries-32batch',
#   'galaxy78/my_awesome_wnut_model',
#   'thongnef/bert-finetuned-ner-cti',
#   'honeyybadger/bert-finetuned-ner',
#   'iyoussef1079/bert-finetuned-ner',
#   'galaxy78/ChatGPT_Project',
#   'sunny2309/bert-finetuned-for-ner',
#   'May33/bert-finetuned-ner',
#   'annabellehuether/bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'mireiaplalis/bert-finetuned-ner-cadec',
#   'mireiaplalis/bert-base-cased-finetuned-ner-cadec',
#   'annabellehuether/t5-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'annabellehuether/bert-base-cased-news-16batch_10epoch_2e5lr_01wd',
#   'annabellehuether/bert-base-cased-news-16batch_5epoch_2e5lr_1wd',
#   'annabellehuether/bert-base-cased-news-16batch_5epoch_2e5lr_01wd',
#   'annabellehuether/100tok-t5-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'charlie1111/bert-finetuned-squad',
#   'hfjbkim/bert-finetuned-ner',
#   'JHhan/bert-finetuned-ner',
#   'annabellehuether/100tok-pegasus-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'skonmeme/bert-finetuned-ner',
#   'csNoHug/bert-base-cased-finetuned-ner-cadec',
#   'Nurmukhamed/bert-finetuned-ner',
#   'meribabayaan/bert-base-cased-finetuned-wikitext2',
#   'Di99di/bert-base-cased-finetuned-wikitext2',
#   'annabellehuether/pegasus-200tok-summaries-bert-base-cased-news-16batch_3epoch_2e5lr_01wd',
#   'AbhishekkV19/test_trainer',
#   'delayedkarma/bert-finetuned-ner',
#   'milenamoreira/bert-finetuned-squad',
#   'sumeyyecelik/my_qa_model',
#   'sandorscog/judicial_brazil',
#   'linqus/bert-finetuned-ner',
#   'mogam/bert-base-cased-wikitext2',
#   'dadashzadeh/bert-base-news-or-informational-nft-english',
#   'vmg1957/bert-finetuned-squad',
#   'rudyTzhan/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-5k-vul-hyp-exp',
#   'AbhishekkV19/bert-base-cased-5k-vul-hyp-exp-10ep',
#   'delayedkarma/bert-finetuned-squad',
#   'jungwoo9/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-exp-10ep',
#   'ShynBui/s27',
#   'Prezily/bert-yelp',
#   'jinya425/bert-base-cased_for_sentiment_analysis',
#   'Shriganesh/bert-finetuned-ner',
#   'Dangurangu/bert-finetuned-ner',
#   'alexpaunoiu/bert_finetune_classification',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-10w-exp-10ep',
#   'tornqvistmax/bert-finetuned-ner',
#   'Hyun24/bert-finetuned-ner',
#   'Katster/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-10w-exp-10ep-s42-1',
#   'AbhishekkV19/bert-base-cased-5kvul-10aug-3nsfw-10w-exp-10ep-s42-2',
#   'quantman/bert-finetuned-ner',
#   'eeeelzvt/bert-base-cased-finetuned-wikitext2',
#   'AravindVCyber/bert-fine-tuned-cola',
#   'mireiaplalis/bert-base-cased-finetuned-ner-cadec-no-iob',
#   'raoel/bert-finetuned-ner',
#   'sul-lix/bert-fine-tuned-cola',
#   'tornqvistmax/bert_finetuned_ner_a',
#   'Castling/bert-finetuned-ner',
#   'tornqvistmax/bert_finetuned_ner_b',
#   'naninya/bert-finetuned-ner',
#   'kondakovilia/bert-base-cased-finetuned-wikitext2',
#   'mialby/bert-base-cased-finetuned-wikitext2',
#   'ArchiRad/bert-base-cased-finetuned-wikitext2',
#   'Yzuygulama/bert-finetuned-squad',
#   'AJlEXANDR/bert-base-cased-finetuned-wikitext2',
#   'Numerical-wizard/bert-base-cased-finetuned-wikitext2',
#   'ichmrklv/bert-base-cased-finetuned-wikitext2',
#   'meoskis/bert-base-cased-finetuned-wikitext2',
#   'MrGummyl3ear/bert-base-cased-finetuned-wikitext2',
#   'MANTISS13/bert-base-cased-finetuned-wikitext2',
#   'Prokopeva/bert-base-cased-finetuned-wikitext2',
#   'No-Sock/bert-base-cased-finetuned-wikitext2',
#   'ksushausenko/bert-base-cased-finetuned-wikitext2',
#   'Azaliya-Vagizova/bert-base-cased-finetuned-wikitext2',
#   'userdiawatch/bert-base-cased-finetuned-wikitext2',
#   'luckykittty/bert-base-cased-finetuned-wikitext2',
#   'winehertz/bert-base-cased-finetuned-wikitext2',
#   'Alena-Poluboyarinova/bert-base-cased-finetuned-wikitext2',
#   'Maxlin12/bert-base-cased-finetuned-wikitext2',
#   'Shriganesh/bert-finetuned-squad',
#   'polina164/bert-base-cased-finetuned-wikitext2',
#   'GlebPS/bert-base-cased-finetuned-wikitext2',
#   'olga-mi-2002/bert-base-cased-finetuned-wikitext2',
#   'qwebeklu4ik/bert-base-cased-finetuned-wikitext2',
#   'MaksKhramtsov/bert-base-cased-finetuned-wikitext2',
#   'esakov-s/bert-base-cased-finetuned-wikitext2',
#   'Memori707/bert-base-cased-finetuned-wikitext2',
#   'Kyyoto/bert-base-cased-finetuned-wikitext2',
#   'raoel/bert-finetuned-squad',
#   'rinkorn/bert-finetuned-ner',
#   'vmg1957/test_trainer',
#   'abhir00p/bert-finetuned-squad-rup',
#   'abhir00p/bert-finetuned-squad-rup-1',
#   'Rezakakooee/bert-finetuned-ner',
#   'xxxxxcz/dihuxia',
#   'neural-net-rahul/bert-finetuned-ner',
#   'Artanis1551/bert_trainer',
#   'koakande/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42',
#   'AbhishekkV19/bert-base-cased-ft5-6ep-s42',
#   'beskrovnayaaaa/bert-base-cased-finetuned-wikitext2',
#   'rafaelperezctes/mi-super-modelo',
#   'EleanorLin/bert-finetuned-squad',
#   'Artanis1551/bert_sentiment_trainer',
#   'hemarun/bert-finetuned-ner',
#   'zeon8985army/bert-base-bible2',
#   'wenjun123/token_calssification_model',
#   'neural-net-rahul/distilbert-finetuned-imdb',
#   'zeon8985army/bert-base-bible3',
#   'zeon8985army/bert-base-bible3-numbers',
#   'zeon8985army/bert-base-bible4',
#   'Karachik/bert-base-cased-finetuned-wikitext2',
#   'chvas37/bert-base-cased-finetuned-wikitext2',
#   'JoseAntonioBarrancoBernabe/mi-super-modelo',
#   'wgpak/bert-finetuned-ner',
#   'Dagonez/bert-finetuned-squad',
#   'jnmrr/bert-finetuned-squad',
#   'MinhMinh09/span-marker-bert-base-fewnerd-coarse-super',
#   'TaupoB/bert-base-cased-finetuned-wikitext2',
#   'andrewma5/bert-finetuned-ner-tutorial',
#   'AnnaKupri/bert-base-cased-finetuned-wikitext2',
#   'jay-dit/bert-base-cased-finetuned-wikitext2',
#   'neural-net-rahul/bert-finetuned-squad',
#   'smallfish166/bert-finetuned-ner',
#   'Alchem/bert-finetuned-squad',
#   'Bramve/bert-finetuned-ner-CRF',
#   'Bramve/bert-finetuned-ner-bilstm',
#   'qualis2006/bert-finetuned-ner',
#   'GandegaH/bert-base-cased-wikitext2',
#   'GandegaH/bert-base-cased-finetuned-wikitext2',
#   'nademaaltijd/bert-finetuned-ner',
#   'cmunhozc/news-ranking-ft-bert',
#   'eunseol/bert-finetuned-ner',
#   'Lipas007/bert-finetuned-ner',
#   'NastyaKorneeva/bert-base-cased-finetuned-wikitext2',
#   'BanUrsus/bert-finetuned-ner_NLP-course-chapter7-section1',
#   'Stefan228/bert-base-cased-finetuned-wikitext2',
#   'peni0k/bert-base-cased-finetuned-wikitext2',
#   'Vishu7797/bert-finetuned-ner',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-2',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-exp3',
#   'adsazad/sikhchat-transformer',
#   'rafaelzimmermann/bert-finetuned-ner',
#   'rafaelzimmermann/bert-finetuned-squad',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-toplessonly',
#   'AbhishekkV19/bert-base-cased-ft6-3ep-s42-no-topless',
#   'jth1911/bert-finetuned-ner',
#   'vladoksss/bert-base-cased-finetuned-wikitext2',
#   'pnr-svc/bert-en-ner',
#   'plusbdw/bert-finetuned-ner',
#   'lourvalli/bert-finetuned-ner',
#   'ilbaks/bert-finetuned-ner',
#   'Sphealls/bert-base-cased-finetuned-wikitext2',
#   'AntonZhar/bert-base-cased-finetuned-wikitext2',
#   'amasiukevich/dummy_bert_model',
#   '4kew/bert-finetuned-squad',
#   'ricerlu/bert-finetuned-ner',
#   'SharonTudi/DIALOGUE_second_model',
#   'KDarrrya/bert-base-cased-finetuned-wikitext2',
#   'raoel/bert-finetuned-ASAP-AEStask',
#   'rinkorn/bert-finetuned-squad',
#   'yunakuz/bert-base-cased-finetuned-wikitext2',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42-v2',
#   'rjomega/bert-finetuned-squad',
#   'Utshav/bert-fined-tuned-cola',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42-exp1',
#   'AbhishekkV19/bert-base-cased-ft5-3ep-s42-exp2',
#   'TunahanGokcimen/tun-en-ner',
#   'TunahanGokcimen/Question-Answering-Bert-base-cased-new',
#   'mikrz/bert-vir_naeus-ner',
#   'AbhishekkV19/bert-base-cased-ft5-topless-sent-removed-3ep-s42',
#   'AbhishekkV19/bert-base-cased-ft5-topless-wrd-removed-3ep-s42',
#   'AbhishekkV19/bert-base-cased-ft5-topless-wrd-0-label-added-3ep-s42',
#   'JeaHyung/test_trainer',
#   'merthacioglu/bert-base-cased-finetuned-squad-b16',
#   'stanpony/medical-diagnosis-classification-model',
#   'stanpony/medical-diagnosis-classifier',
#   'raj-p/bert-finetuned-ner',
#   'FocacciaX/bert-finetuned-ner',
#   'BenRongey/GoEmo',
#   'nguyenthanhasia/RuletakerBert',
#   'rohitdiwane/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-mnli-model1',
#   'varun-v-rao/bert-base-cased-mnli-model2',
#   'varun-v-rao/bert-base-cased-mnli-model3',
#   'varun-v-rao/bert-base-cased-mnli-model4',
#   'monkeyerKong/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-mnli-model5',
#   'varun-v-rao/bert-base-cased-mnli-model6',
#   'varun-v-rao/bert-base-cased-mnli-model7',
#   'varun-v-rao/bert-base-cased-mnli-model8',
#   'varun-v-rao/bert-base-cased-mnli-model9',
#   'varun-v-rao/bert-base-cased-mnli-model10',
#   'Brrrrt/bert-finetuned-squad',
#   'ovieyra21/mi-super-modelo',
#   'varun-v-rao/bert-base-cased-snli-model1',
#   'varun-v-rao/bert-base-cased-snli-model2',
#   'varun-v-rao/bert-base-cased-snli-model3',
#   'raj-p/bert-finetuned-ner-medical',
#   'varun-v-rao/bert-base-cased-snli-model4',
#   'varun-v-rao/bert-base-cased-snli-model5',
#   'varun-v-rao/bert-base-cased-snli-model6',
#   'varun-v-rao/bert-base-cased-snli-model7',
#   'varun-v-rao/bert-base-cased-snli-model8',
#   'varun-v-rao/bert-base-cased-snli-model9',
#   'varun-v-rao/bert-base-cased-snli-model10',
#   'jarekr/bert-finetuned-squad',
#   'clecam/bert-fine-tune-cola',
#   'mahmed31/bert-finetuned-ner',
#   'ConorParis32/dummy',
#   'sevvalozdamar/bert-base-cased-finetuned',
#   'zanetworker/bert-finetuned-ner',
#   'Kaelan/bert-finetuned-squad',
#   'jarektovar/mi-super-modelo',
#   'Malek1410/bert_project_test_trainer',
#   'ConorParis32/TFdummy',
#   'moctarsmal/bert-ner-chunks',
#   '4n7h0ny/fin3Tun3Glu3',
#   'hwang2006/bert-finetuned-squad',
#   'Quanult/bert-finetuned-ner',
#   'jsathish1990/test_trainer',
#   'rcade/test_falcon_model_learning',
#   'TunahanGokcimen/bert-base-cased-ner',
#   'katzenbach/test_trainer',
#   'Soon2340/bert-finetuned-ner',
#   'rcade/finetuned-bert-mrpc',
#   'rcade/glue_rcade_test_model',
#   'rcade/testing_model',
#   'katzenbach/PrimerClasificadorSencillo',
#   'sheduele/bert_C_2',
#   'yukihirop/bert-finetuned-squad',
#   'bmd1905/bert-finetuned-squad',
#   'ccova/mi-super-modelo',
#   'llkenll/BertModel',
#   'brightlee6/test_trainer',
#   'shahzebnaveed/bert-finetuned-squad',
#   'syedmhamudulhasan/bert-base-cased-wikitext2',
#   'katzenbach/testMetaphor',
#   'katzenbach/testMetaphor2',
#   'BanUrsus/bert-base-cased-finetuned-squad_nlp-course-chapter7-section6',
#   'AhmedKaisar/bert-ner',
#   'mrvsrc/bert-finetuned-ner',
#   'YeoJiSu/bert-fine-tuned-cola',
#   'katzenbach/testMetaphor3',
#   'Capstone-lpx/my_awesome_eli5_mlm_model',
#   'bSariturk/bert-fine-tuned-cola',
#   'Palistha/bert-finetuned-ner',
#   'eagle0504/finetuned-bert-mrpc',
#   'DanielAvelar09/mi-super-model',
#   'azureabaaba/bert-finetuned-squad',
#   'Palistha/bert-finetuned-squad',
#   'YeoJiSu/bert-finetuned-ner',
#   'Kamaljp/bert-base-cased-wiki',
#   'sbulut/bert-finetuned-ner',
#   'manibt1993/ncbi_disease_ner',
#   'Siddharthparmar7/bookcorpus_MLM',
#   'suyu0712/bert-finetuned-squad',
#   'timothee1996/bert-finetuned-ner',
#   'sbulut/bert-finetuned-squad',
#   'Skier8402/bert-finetuned-ner',
#   'HeZhang1019/bert-finetuned-squad',
#   'DjSteker/mi-super-modelo',
#   'manibt1993/huner_ncbi_disease',
#   'rahhal/bert-finetuned-squad',
#   'Raymond0012/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-lora-592K-snli-model1',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-snli-model1',
#   'varun-v-rao/bert-base-cased-lora-592K-snli-model2',
#   'varun-v-rao/bert-base-cased-lora-592K-snli-model3',
#   'StatsGary/bert-cola-finetuned',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-snli-model2',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-snli-model3',
#   'blaze999/finetuned-ner-conll',
#   'manibt1993/huner_disease',
#   'micoff/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-squad-model1',
#   'Ankush-Chander/bert-finetuned-ner',
#   'gavinqiangli/bert-base-cased-wikitext2',
#   'varun-v-rao/bert-base-cased-lora-591K-squad-model1',
#   'varun-v-rao/bert-base-cased-squad-model2',
#   'varun-v-rao/bert-base-cased-lora-591K-squad-model2',
#   'varun-v-rao/bert-base-cased-lora-591K-squad-model3',
#   'varun-v-rao/bert-base-cased-squad-model3',
#   'felixng2k/bert-finetuned-ner',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-squad-model1',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-squad-model2',
#   'varun-v-rao/bert-base-cased-bn-adapter-895K-squad-model3',
#   'Shruthi-S/shruthicapstone-bertbase-qa',
#   'rtdoit/bert-fine-tuned-cola',
#   'yacineai7/bert-finetuned-ner',
#   'Priyanshuchaudhary2425/AI-Text-Ditactor',
#   'Rajdonthi/bert-finetuned-ner',
#   'serhii-korobchenko/bert-finetuned-ner',
#   'SamBuchl/bert-finetuned-ner',
#   'Khaledai/test-trainer',
#   'sophiayk20/bert-finetuned-squad',
#   'Nattipon/bert-finetuned-squad',
#   'destinyg423/bert-finetuned-ner',
#   'lbukowiec/bert-finetuned-ner',
#   'Hlindroth/test_trainer',
#   'McChicken/bert-finetuned-squad',
#   'Shruthi-S/capstone-bert-qa',
#   'Fm505/bert-finetuned-ner',
#   'gskhs/bert-finetuned-squad',
#   'rahulshah9713/bert-base-cased-wikitext2',
#   'lorisrossi/test-bert-finetuned-cola',
#   'sjunique/bert-finetuned-ner',
#   'tormartin/bert-finetuned-squad',
#   'alexyuanj/bert-finetuned-squad',
#   'Peak1260/bert-finetuned-squad',
#   'Hernan1970/mi-super-modelo',
#   'PW1116/bert-finetuned-squad',
#   'ttamer/bert-finetuned-squad',
#   'jasontnguyen/bert-finetuned-squad',
#   'Cesar2109/mi-super-modelo',
#   'felixbrock/test_trainer',
#   'ruru2701/filmbert_v1',
#   'ruru2701/Models',
#   'ruru2701/filmbertv1',
#   'ThuyNT03/SOMD-train-bert-v1',
#   'sjunique/bert-finetuned-squad',
#   'Pegaso183/clasificador_estrellas',
#   'JacobEisner/bert-finetuned-squad',
#   'liminding/bert-finetuned-squad',
#   'neimp/bert-finetuned-squad',
#   'duykha0511/bert-base-cased_',
#   'Dakotazoid56/bert-finetuned-squad',
#   'kannt-im/bert-finetuned-ner',
#   'noelg02/mi-super-modelo',
#   'surribasg/mi-super-modelo',
#   'nbelle/bert-finetuned-squad',
#   'anshuman-ucsb/bert-finetuned-squad',
#   'junghyun-tiger/bert-finetuned-squad',
#   'ThuyNT03/SOMD-train-bert-v2',
#   'julianfrank1151/bert-finetuned-squad',
#   'minshengchan/bert-finetuned-ner',
#   'Bzhao344/bert-finetuned-squad',
#   'cxbn12/bert-finetuned-ner',
#   'ThuyNT03/SOMD-train-bert-v3',
#   'ethan3048/bert-finetuned-squad',
#   'chosenone80/bert-ner-test-1',
#   'pabsdsr/bert-finetuned-squad',
#   'thecriticalpoint/test_trainer',
#   'free126/bert-finetuned-squad',
#   'siru712/bert-finetuned-squad',
#   'farfalla/bert-finetuned-ner',
#   'kpazawala/bert-finetuned-squad',
#   'mr-rov/bert-base-casedhealth_model1',
#   'mr-rov/test_trainer',
#   'chosenone80/bert-ner-test-2',
#   'yang598/bert-finetuned-squad',
#   'christianbaker/bert-finetuned-squad',
#   'jasonjongwoo/bert-finetuned-squad',
#   'tschlunk/bert-finetuned-squad',
#   'ashleybudman/bert-finetuned-squad',
#   'SNHE/bert-fine-tuned-cola',
#   'engmufic/finetuned-model',
#   'sadhaklal/bert-base-cased-finetuned-conll2003-ner',
#   'newyorksteak/bert-finetuned-squad',
#   'wrschiff/bert-finetuned-squad',
#   'Elizabeth2002/bert-finetuned-squad',
#   'hj279559/bert-finetuned-squad',
#   'NastasiaM/bert-finetuned-squad',
#   'seculoro1/bert-finetuned-squad',
#   'ondinehunter/bert-finetuned-squad',
#   'KhosrojerdiA/bert-finetuned-ner',
#   'tianyuzhangterry/bert-finetuned-ner',
#   'phusroyal/bert-base-cased-massive_intent',
#   'VikrantRamesh/bert-base-cased-wikitext2',
#   'Norms02/bert-finetuned-squad',
#   'DrGwin/bert-base-cased-finetuned-swag',
#   'yousseftarhri/bert-base-cased_fine_tuned',
#   'AICHEN008/bert-finetuned-ner',
#   'teknow/test_trainer',
#   'rfdv/bert-fine-tuned-cola',
#   'Corbanp/bert-finetuned-ner',
#   'ab-ai/pii_model',
#   'Davidzhang123/bert-fine-tuned-cola',
#   'jamesLeeeeeee/code-search-net-tokenizer',
#   'Mayank1999/bert-finetuned-ner',
#   'Skier8402/bert-finetuned-squad',
#   'nitinai/bert-finetuned-ner',
#   'jerrish/bert-finetuned-ner',
#   'Concises/bert-finetuned-ner',
#   'Sebas012/mi-super-modelo',
#   'mithegooie/bert-finetuned-ner',
#   'Fah-d/bert-finetuned-ner',
#   'CHENG028/bert-finetuned-squad',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K1',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K2',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K3',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K4',
#   'dtorber/PAN-2024-transformer-base_bert-base-cased_K5',
#   'dtorber/bert-base-cased_K1',
#   'dtorber/bert-base-cased_K2',
#   'dtorber/bert-base-cased_K3',
#   'dtorber/bert-base-cased_K4',
#   'dtorber/bert-base-cased_K5',
#   'willherbert27/bert-finetuned-combo-textbook',
#   'Ernani/bert-finetuned-ner',
#   'WhisperHeart/my_awesome_model',
#   'Sourabh1407/bert-finetuned-squad',
#   'akshit-g/distilbert-base-cased',
#   'shubhamgantayat/reward_model_anthropic',
#   'dtorber/bert-base-cased',
#   'mhassan101/bert-finetuned-squad-ds',
#   'dhanushbitra/bert_sentiment_trainer',
#   'gingun18/bert-finetuned-ner',
#   'rizvi-rahil786/bert-base-canadaWildfire',
#   'alex-atelo/bert-finetuned-ner',
#   'asifabcder/bert-finetuned-ner',
#   'rizvi-rahil786/bert-base-cased-equadorEarthquake',
#   'rizvi-rahil786/bert-base-cased-cyclonePam',
#   'rizvi-rahil786/bert-base-cased-greeceWildfire',
#   'rizvi-rahil786/bert-base-cased-laShoot',
#   'rizvi-rahil786/bert-base-cased-matthewCategory',
#   'rizvi-rahil786/bert-base-cased-mexicoQuake',
#   'rizvi-rahil786/bert-base-cased-usflood',
#   'lukeBB/bert-finetuned-squad',
#   'rizvi-rahil786/bert-base-cased-shShooting',
#   'rizvi-rahil786/bert-base-cased-pakQuake',
#   'rizvi-rahil786/bert-base-cased-hblast',
#   'rizvi-rahil786/bert-base-cased-uflood',
#   'rizvi-rahil786/bert-base-cased-kaikouraEarthquake',
#   'emptyasso/uploadhub',
#   'vicky6/bert-finetuned-ner',
#   'who-does/bert-base-cased-wikitext2',
#   'rizvi-rahil786/bert-base-cased-hardaDerail',
#   'rizvi-rahil786/bert-base-cased-hagupitCategory',
#   'siddharth2050/sid-ner',
#   'GorBatchLab/bert-finetuned-squad',
#   'mithegooie/bert-finetuned-squad',
#   'lloydmeta/bert-fine-tuned-cola',
#   'michaelcheung/bert-finetuned-ner',
#   'serhii-korobchenko/bert-finetuned-squad',
#   'PrasannaL/test_trainer',
#   ...],
#  'quantized': ['Xenova/bert-base-cased', 'wdavies/extract-answer-from-text'],
#  'ModelArchitecture': 'transformers',
#  'Purpose': 'sequence classification, token classification or question answering',
#  'ModelTrainingTime': 'one million steps',
#  'MaintainerContact': None,
#  'RelatedDocumentation': None,
#  'CommunityFeedback': None,
#  'InferenceSpeed': None,
#  'PerformanceMetric': 'Glue test results: MNLI-(m/mm), QQP, QNLI, SST-2, CoLA, STS-B, MRPC, RTE',
#  'KnownLimitations': 'biased predictions',
#  'IntendedUse': 'masked language modeling, next sentence prediction, fine-tuning on downstream tasks',
#  'EthicalConsiderations': 'biased predictions'}

# %%
folder_path = f"./models/{model_name}/"  # 저장할 폴더
file_path = os.path.join(folder_path, "merged_data.json")

# 폴더가 없으면 생성
os.makedirs(folder_path, exist_ok=True)

# JSON 저장
with open(file_path, "w", encoding="utf-8") as f:
    json.dump(merged_dict, f, indent=4, ensure_ascii=False)

print(f"파일 저장 완료: {file_path}")
# Out:
# 파일 저장 완료: ./models/bert-base-cased/merged_data.json
